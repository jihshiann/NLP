# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# File ‘bbc_text_cls.csv’ already there; not retrieving.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
df = pd.read_csv('bbc_text_cls.csv')

# %%
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
df['targets'] = df['labels'].astype("category").cat.codes

# %%
# number of classes
K = df['targets'].max() + 1
K
# Out:
# 5

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
# Convert sentences to sequences
MAX_VOCAB_SIZE = 2000
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(df_train['text'])
sequences_train = tokenizer.texts_to_sequences(df_train['text'])
sequences_test = tokenizer.texts_to_sequences(df_test['text'])

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
V = len(word2idx)
print('Found %s unique tokens.' % V)
# Out:
# Found 27596 unique tokens.

# %%
# pad sequences so that we get a N x T matrix
data_train = pad_sequences(sequences_train)
print('Shape of data train tensor:', data_train.shape)

# get sequence length
T = data_train.shape[1]
# Out:
# Shape of data train tensor: (1557, 2837)

# %%
data_test = pad_sequences(sequences_test, maxlen=T)
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data test tensor: (668, 2837)

# %%
# Create the model

# We get to choose embedding dimensionality
D = 50

# Note: we actually want to the size of the embedding to (V + 1) x D,
# because the first index starts from 1 and not 0.
# Thus, if the final index of the embedding matrix is V,
# then it actually must have size V + 1.

i = Input(shape=(T,))
x = Embedding(V + 1, D)(i)
x = Conv1D(32, 3, activation='relu')(x)
# x = MaxPooling1D(3)(x)
# x = Conv1D(64, 3, activation='relu')(x)
# x = MaxPooling1D(3)(x)
# x = Conv1D(128, 3, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(K)(x)

model = Model(i, x)

# %%
# Compile and fit
model.compile(
  loss=SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)


print('Training model...')
r = model.fit(
  data_train,
  df_train['targets'],
  epochs=50,
  validation_data=(data_test, df_test['targets'])
)
# Out:
# Training model...
# Epoch 1/50
# 49/49 [==============================] - 8s 154ms/step - loss: 1.5653 - accuracy: 0.3719 - val_loss: 1.4984 - val_accuracy: 0.5704
# Epoch 2/50
# 49/49 [==============================] - 7s 133ms/step - loss: 1.3352 - accuracy: 0.7367 - val_loss: 1.1636 - val_accuracy: 0.8308
# Epoch 3/50
# 49/49 [==============================] - 12s 245ms/step - loss: 0.8625 - accuracy: 0.8838 - val_loss: 0.6538 - val_accuracy: 0.8862
# Epoch 4/50
# 49/49 [==============================] - 11s 231ms/step - loss: 0.4410 - accuracy: 0.9261 - val_loss: 0.3895 - val_accuracy: 0.9162
# Epoch 5/50
# 49/49 [==============================] - 7s 148ms/step - loss: 0.2504 - accuracy: 0.9544 - val_loss: 0.2909 - val_accuracy: 0.9296
# Epoch 6/50
# 49/49 [==============================] - 8s 172ms/step - loss: 0.1635 - accuracy: 0.9730 - val_loss: 0.2436 - val_accuracy: 0.9341
# Epoch 7/50
# 49/49 [==============================] - 8s 166ms/step - loss: 0.1126 - accuracy: 0.9852 - val_loss: 0.2131 - val_accuracy: 0.9401
# Epoch 8/50
# 49/49 [==============================] - 7s 134ms/step - loss: 0.0809 - accuracy: 0.9910 - val_loss: 0.1933 - val_accuracy: 0.9446
# Epoch 9/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0590 - accuracy: 0.9949 - val_loss: 0.1798 - val_accuracy: 0.9461
# Epoch 10/50
# 49/49 [==============================] - 7s 136ms/step - loss: 0.0436 - accuracy: 0.9968 - val_loss: 0.1720 - val_accuracy: 0.9491
# Epoch 11/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.0330 - accuracy: 0.9987 - val_loss: 0.1660 - val_accuracy: 0.9476
# Epoch 12/50
# 49/49 [==============================] - 7s 134ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9491
# Epoch 13/50
# 49/49 [==============================] - 8s 154ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9491
# Epoch 14/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9476
# Epoch 15/50
# 49/49 [==============================] - 7s 135ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9506
# Epoch 16/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9506
# Epoch 17/50
# 49/49 [==============================] - 7s 134ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9506
# Epoch 18/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9506
# Epoch 19/50
# 49/49 [==============================] - 7s 135ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9506
# Epoch 20/50
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9506
# Epoch 21/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9521
# Epoch 22/50
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9521
# Epoch 23/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9521
# Epoch 24/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9506
# Epoch 25/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9506
# Epoch 26/50
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9521
# Epoch 27/50
# 49/49 [==============================] - 7s 142ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9521
# Epoch 28/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9506
# Epoch 29/50
# 49/49 [==============================] - 7s 134ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9521
# Epoch 30/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9521
# Epoch 31/50
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9521
# Epoch 32/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9536
# Epoch 33/50
# 49/49 [==============================] - 7s 134ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9536
# Epoch 34/50
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9521
# Epoch 35/50
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9521
# Epoch 36/50
# 49/49 [==============================] - 7s 136ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9521
# Epoch 37/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9521
# Epoch 38/50
# 49/49 [==============================] - 7s 135ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9521
# Epoch 39/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9521
# Epoch 40/50
# 49/49 [==============================] - 7s 135ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9521
# Epoch 41/50
# 49/49 [==============================] - 8s 159ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9521
# Epoch 42/50
# 49/49 [==============================] - 8s 156ms/step - loss: 9.4636e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9521
# Epoch 43/50
# 49/49 [==============================] - 7s 136ms/step - loss: 8.8972e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9521
# Epoch 44/50
# 49/49 [==============================] - 8s 158ms/step - loss: 8.4104e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9521
# Epoch 45/50
# 49/49 [==============================] - 7s 136ms/step - loss: 7.9271e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9521
# Epoch 46/50
# 49/49 [==============================] - 8s 159ms/step - loss: 7.5090e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9521
# Epoch 47/50
# 49/49 [==============================] - 6s 132ms/step - loss: 7.1076e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9521
# Epoch 48/50
# 49/49 [==============================] - 8s 156ms/step - loss: 6.7372e-04 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9521
# Epoch 49/50
# 49/49 [==============================] - 7s 142ms/step - loss: 6.3848e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9521
# Epoch 50/50
# 49/49 [==============================] - 7s 140ms/step - loss: 6.0640e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9521

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();
