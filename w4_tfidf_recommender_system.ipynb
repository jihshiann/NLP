# %%
# https://www.kaggle.com/tmdb/tmdb-movie-metadata
# !wget https://lazyprogrammer.me/course_files/nlp/tmdb_5000_movies.csv
# Out:
# --2024-03-13 03:44:16--  https://lazyprogrammer.me/course_files/nlp/tmdb_5000_movies.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-03-13 03:44:16 ERROR 403: Forbidden.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

# %%
df = pd.read_csv('tmdb_5000_movies.csv')

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
x = df.iloc[0]
x
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# runtime                                                             162.0
# spoken_languages        [{"iso_639_1": "en", "name": "English"}, {"iso...
# status                                                           Released
# tagline                                       Enter the World of Pandora.
# title                                                              Avatar
# vote_average                                                          7.2
# vote_count                                                          11800
# Name: 0, dtype: object

# %%
x['genres']
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
x['keywords']
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
j = json.loads(x['genres'])
j
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
' '.join(''.join(jj['name'].split()) for jj in j)
# Out:
# 'Action Adventure Fantasy ScienceFiction'

# %%
# convert the relevant data for each movie into a single string
# to be ingested by TfidfVectorizer
def genres_and_keywords_to_string(row):
  genres = json.loads(row['genres'])
  genres = ' '.join(''.join(j['name'].split()) for j in genres)

  keywords = json.loads(row['keywords'])
  keywords = ' '.join(''.join(j['name'].split()) for j in keywords)
  return "%s %s" % (genres, keywords)

# %%
# create a new string representation of each movie
df['string'] = df.apply(genres_and_keywords_to_string, axis=1)

# %%
df['string']
# Out:
# 0       Action Adventure Fantasy ScienceFiction cultur...
# 1       Adventure Fantasy Action ocean drugabuse exoti...
# 2       Action Adventure Crime spy basedonnovel secret...
# 3       Action Crime Drama Thriller dccomics crimefigh...
# 4       Action Adventure ScienceFiction basedonnovel m...
#                               ...
# 4798    Action Crime Thriller unitedstates–mexicobarri...
# 4799                                      Comedy Romance
# 4800    Comedy Drama Romance TVMovie date loveatfirsts...
# 4801
# 4802      Documentary obsession camcorder crush dreamgirl
# Name: string, Length: 4803, dtype: object

# %%
# create a tf-idf vectorizer object
tfidf = TfidfVectorizer(max_features=2000)

# %%
# create a data matrix from the overviews
X = tfidf.fit_transform(df['string'])

# %%
X
# Out:
# <4803x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 37285 stored elements in Compressed Sparse Row format>

# %%
tfidf.vocabulary_
# Out:
# {'action': 12,
#  'adventure': 26,
#  'fantasy': 644,
#  'sciencefiction': 1531,
#  'cultureclash': 437,
#  'future': 722,
#  'spacecolony': 1654,
#  'society': 1638,
#  'spacetravel': 1661,
#  'futuristic': 723,
#  'romance': 1484,
#  'space': 1652,
#  'alien': 50,
#  'tribe': 1832,
#  'alienplanet': 56,
#  'cgi': 312,
#  'marine': 1068,
#  'soldier': 1641,
#  'battle': 180,
#  'mindandsoul': 1114,
#  '3d': 10,
#  'ocean': 1236,
#  'drugabuse': 546,
#  'exoticisland': 613,
#  'eastindiatradingcompany': 571,
#  'loveofone': 1033,
#  'slife': 1625,
#  'traitor': 1818,
#  'shipwreck': 1588,
#  'strongwoman': 1702,
#  'ship': 1587,
#  'afterlife': 34,
#  'fighter': 672,
#  'pirate': 1316,
#  'swashbuckler': 1744,
#  'aftercreditsstinger': 33,
#  'crime': 422,
#  'spy': 1674,
#  'basedonnovel': 168,
#  'secretagent': 1545,
#  'sequel': 1563,
#  'britishsecretservice': 248,
#  'drama': 538,
#  'thriller': 1795,
#  'dccomics': 458,
#  'crimefighter': 424,
#  'terrorist': 1782,
#  'secretidentity': 1548,
#  'burglar': 260,
#  'hostagedrama': 857,
#  'timebomb': 1799,
#  'gothamcity': 759,
#  'vigilante': 1899,
#  'cover': 415,
#  'up': 1871,
#  'superhero': 1722,
#  'tragichero': 1813,
#  'terrorism': 1781,
#  'destruction': 491,
#  'imax': 881,
#  'mars': 1074,
#  'medallion': 1090,
#  'princess': 1385,
#  'steampunk': 1685,
#  'escape': 596,
#  'superhumanstrength': 1725,
#  '19thcentury': 8,
#  'dualidentity': 558,
#  'amnesia': 72,
#  'sandstorm': 1512,
#  'forgiveness': 704,
#  'spider': 1664,
#  'wretch': 1981,
#  'deathofafriend': 465,
#  'hostility': 859,
#  'marvelcomic': 1078,
#  'revenge': 1467,
#  'animation': 87,
#  'family': 635,
#  'hostage': 856,
#  'magic': 1051,
#  'horse': 852,
#  'fairytale': 626,
#  'musical': 1168,
#  'basedonfairytale': 165,
#  'duringcreditsstinger': 561,
#  'basedoncomicbook': 164,
#  'vision': 1911,
#  'superheroteam': 1723,
#  'marvelcinematicuniverse': 1077,
#  'witch': 1959,
#  'broom': 250,
#  'schoolofwitchcraft': 1527,
#  'wizardry': 1965,
#  'teenagecrush': 1764,
#  'werewolf': 1943,
#  'superpowers': 1731,
#  'savingtheworld': 1518,
#  'invulnerability': 923,
#  'killing': 967,
#  'undercover': 1854,
#  'fortuneteller': 706,
#  'monster': 1137,
#  'captain': 279,
#  'cardgame': 287,
#  'daughter': 457,
#  'western': 1944,
#  'texas': 1783,
#  'survivor': 1740,
#  'partner': 1284,
#  'outlaw': 1260,
#  'lawyer': 985,
#  'train': 1815,
#  'superhuman': 1724,
#  'alieninvasion': 54,
#  'reboot': 1442,
#  'fictionalplace': 670,
#  'brothersisterrelationship': 254,
#  'lion': 1002,
#  'humanbeing': 864,
#  'matteroflifeanddeath': 1086,
#  'faith': 627,
#  'uncle': 1852,
#  'fantasyworld': 645,
#  'newyork': 1210,
#  'shield': 1586,
#  'sea': 1540,
#  'mutiny': 1179,
#  'sword': 1748,
#  'primeminister': 1383,
#  'sailing': 1506,
#  'duke': 560,
#  'mermaid': 1101,
#  'comedy': 372,
#  'timetravel': 1801,
#  'timemachine': 1800,
#  'corruption': 404,
#  'elves': 583,
#  'dwarves': 562,
#  'orcs': 1251,
#  'middle': 1108,
#  'earth': 569,
#  'tolkien': 1802,
#  'hobbit': 830,
#  'dragon': 537,
#  'unlikelyfriendship': 1867,
#  'swordandsorcery': 1749,
#  'lossoffather': 1017,
#  'geneticengineering': 740,
#  'socialoutcast': 1637,
#  'knight': 974,
#  'middleages': 1109,
#  'wizard': 1964,
#  'england': 589,
#  'experiment': 616,
#  'orphan': 1255,
#  'animal': 84,
#  'basedonyoungadultnovel': 176,
#  'showbusiness': 1597,
#  'filmmaking': 676,
#  'filmproducer': 678,
#  'dinosaur': 503,
#  'panic': 1270,
#  'epic': 592,
#  'love': 1029,
#  'disaster': 507,
#  'tragiclove': 1814,
#  'classdifferences': 351,
#  'starcrossedlovers': 1683,
#  '1910s': 1,
#  'civilwar': 349,
#  'war': 1925,
#  'fight': 671,
#  'navy': 1191,
#  'hongkong': 844,
#  'soccer': 1635,
#  'scientist': 1532,
#  'dna': 520,
#  'tyrannosaurusrex': 1850,
#  'island': 930,
#  'suspense': 1742,
#  'amusementpark': 74,
#  'animalattack': 85,
#  'animalhorror': 86,
#  'sociopath': 1639,
#  'killer': 964,
#  'artgallery': 116,
#  'doctor': 521,
#  'death': 464,
#  'supervillain': 1732,
#  'waronterror': 1932,
#  'tennessee': 1777,
#  'malibu': 1058,
#  'queen': 1422,
#  'mutant': 1176,
#  'dormitory': 532,
#  'games': 728,
#  'bestfriend': 195,
#  'university': 1866,
#  'egypt': 578,
#  'sun': 1717,
#  'chaos': 315,
#  'tank': 1756,
#  'robot': 1478,
#  'giantrobot': 749,
#  'circus': 348,
#  'hope': 849,
#  'lost': 1027,
#  'obsession': 1234,
#  'artificialintelligence': 117,
#  'dystopia': 567,
#  'computer': 383,
#  'deception': 472,
#  'duel': 559,
#  'motorcycle': 1153,
#  'carrace': 293,
#  'anthropomorphism': 92,
#  'transformation': 1819,
#  'alieninfection': 53,
#  'magicalobject': 1052,
#  'college': 365,
#  'toy': 1809,
#  'toycomestolife': 1810,
#  'inanimateobjectscomingtolife': 887,
#  'prophecy': 1400,
#  'sanfrancisco': 1513,
#  'cyborg': 442,
#  'killerrobot': 965,
#  'gasstation': 735,
#  'post': 1354,
#  'apocalyptic': 101,
#  'army': 111,
#  'firearm': 680,
#  'losangeles': 1010,
#  'car': 282,
#  'race': 1423,
#  'horror': 850,
#  'apocalypse': 100,
#  'zombie': 1997,
#  'nuclearweapons': 1228,
#  'zombieapocalypse': 1998,
#  '1970s': 6,
#  'storm': 1693,
#  'spacecraft': 1655,
#  'friendship': 717,
#  'spaceopera': 1658,
#  'giant': 747,
#  'infidelity': 898,
#  'persia': 1302,
#  'basedonvideogame': 175,
#  'giantmonster': 748,
#  'moon': 1139,
#  'bodyguard': 222,
#  'basedoncartoon': 162,
#  'sabotage': 1498,
#  'commando': 377,
#  'riddle': 1469,
#  'whip': 1947,
#  'treasure': 1828,
#  'machinegun': 1045,
#  'mayacivilization': 1087,
#  'peru': 1303,
#  'treasurehunt': 1829,
#  'archaeologist': 105,
#  'indianajones': 893,
#  'archeology': 106,
#  'friends': 716,
#  'alternatehistory': 59,
#  'fear': 660,
#  'nature': 1190,
#  'journey': 952,
#  'scotland': 1533,
#  'rebel': 1440,
#  'bravery': 237,
#  'kingdom': 970,
#  'wish': 1958,
#  'bear': 186,
#  'womandirector': 1968,
#  'courage': 411,
#  'stranded': 1695,
#  'romanticcomedy': 1486,
#  'ambassador': 62,
#  'naturaldisaster': 1189,
#  'endoftheworld': 588,
#  'volcaniceruption': 1913,
#  'holiday': 832,
#  'victorianengland': 1890,
#  'money': 1133,
#  'christmaseve': 340,
#  'ghost': 745,
#  'christmas': 339,
#  'interspeciesromance': 912,
#  'africa': 31,
#  'feralchild': 668,
#  'jungle': 954,
#  'selfsacrifice': 1560,
#  'winter': 1957,
#  'fairy': 625,
#  'talefigure': 1753,
#  'supernaturalpowers': 1729,
#  '1980s': 7,
#  'sadism': 1500,
#  'organizedcrime': 1253,
#  'districtattorney': 516,
#  'agedifference': 35,
#  'balloon': 150,
#  'middleeast': 1110,
#  'armsdealer': 110,
#  'filmdirector': 674,
#  'key': 959,
#  'boy': 232,
#  'basedontvseries': 174,
#  'drag': 536,
#  'antihero': 94,
#  'secretmission': 1552,
#  'villain': 1903,
#  'fathersonrelationship': 657,
#  'marriedcouple': 1073,
#  'father': 653,
#  'marriage': 1070,
#  'rescue': 1457,
#  'dejavu': 474,
#  'tattoo': 1757,
#  'water': 1937,
#  'doomsday': 530,
#  'secret': 1544,
#  'technology': 1762,
#  'government': 760,
#  'president': 1378,
#  'murder': 1163,
#  'attack': 129,
#  'explosion': 618,
#  'evil': 605,
#  'dream': 539,
#  'cartoon': 295,
#  'imaginaryfriend': 880,
#  'moving': 1159,
#  'kids': 962,
#  'snake': 1630,
#  'wolf': 1966,
#  'elephant': 582,
#  'tiger': 1797,
#  'remake': 1454,
#  'talkinganimal': 1755,
#  'immortality': 884,
#  'forest': 703,
#  'woman': 1967,
#  'snowwhite': 1634,
#  'darkfantasy': 451,
#  'adaptation': 17,
#  'leader': 987,
#  'colony': 368,
#  'woods': 1972,
#  'ape': 99,
#  'monkey': 1136,
#  'plague': 1319,
#  'japan': 939,
#  'suicide': 1712,
#  'samurai': 1510,
#  'basedontruestory': 173,
#  'washingtond': 1936,
#  'mystery': 1180,
#  'inventor': 919,
#  'destiny': 489,
#  'brotherbrotherrelationship': 253,
#  'hero': 810,
#  'talent': 1754,
#  'moraldilemma': 1141,
#  'productplacement': 1395,
#  'bullying': 259,
#  'santaclaus': 1514,
#  'nerd': 1200,
#  'gift': 750,
#  'northpole': 1224,
#  'flying': 697,
#  'arena': 108,
#  'night': 1213,
#  'training': 1817,
#  'village': 1901,
#  'viking': 1900,
#  'flight': 691,
#  'combat': 370,
#  'warrior': 1933,
#  'manvsmachine': 1065,
#  'sunglasses': 1718,
#  'firemen': 681,
#  'psychiatrist': 1407,
#  'spaceship': 1659,
#  'outerspace': 1259,
#  'singleparent': 1610,
#  'nasa': 1185,
#  'expedition': 614,
#  'blackhole': 211,
#  'raceagainsttime': 1424,
#  'familyrelationships': 639,
#  'farmhouse': 649,
#  'astronaut': 124,
#  'fatherdaughterrelationship': 654,
#  'singlefather': 1608,
#  'farmer': 648,
#  'spacestation': 1660,
#  'lossoflover': 1019,
#  'kidnapping': 961,
#  'heist': 806,
#  'redemption': 1444,
#  'mountains': 1155,
#  'ring': 1472,
#  'tunnel': 1841,
#  'invisibility': 921,
#  'streetgang': 1697,
#  'auto': 138,
#  'automobileracing': 139,
#  'diary': 499,
#  'funeral': 721,
#  'travel': 1827,
#  'hospital': 855,
#  'cia': 344,
#  '1960s': 5,
#  'revolution': 1468,
#  'fire': 679,
#  'book': 226,
#  'castle': 297,
#  'apprentice': 102,
#  'mission': 1125,
#  'sorcerer': 1644,
#  'newyear': 1209,
#  'seve': 1569,
#  'drowning': 544,
#  'cataclysm': 300,
#  'ball': 148,
#  'self': 1559,
#  'single': 1607,
#  'ambush': 65,
#  'sadness': 1503,
#  'liberationofprisoners': 995,
#  'prince': 1384,
#  'theatreplay': 1789,
#  'heirtothethrone': 805,
#  'assault': 121,
#  'boardingschool': 220,
#  'coupd': 410,
#  'etat': 601,
#  'teacher': 1760,
#  'cowardliness': 418,
#  'pregnancy': 1366,
#  'capture': 281,
#  'videogame': 1893,
#  'chase': 316,
#  'goodvsevil': 756,
#  'king': 969,
#  'history': 826,
#  'nurse': 1232,
#  'patriotism': 1292,
#  'hawaii': 800,
#  'worldwarii': 1978,
#  'pilot': 1314,
#  'pearlharbor': 1293,
#  'airforce': 40,
#  'airplane': 41,
#  'destroy': 490,
#  'teenagehero': 1766,
#  'greece': 768,
#  'homosexuality': 842,
#  'gayrelationship': 738,
#  'ancientworld': 80,
#  'cuttingthecord': 440,
#  'childhero': 327,
#  'dyinganddeath': 564,
#  'sapprentice': 1515,
#  'blackmagic': 212,
#  'sorcery': 1645,
#  'chosenone': 334,
#  'tournament': 1808,
#  'teenager': 1768,
#  'alcohol': 46,
#  'forbiddenlove': 701,
#  'lovers': 1035,
#  'affection': 29,
#  'alcoholism': 49,
#  'alone': 57,
#  'virus': 1910,
#  'pandemic': 1269,
#  'londonengland': 1007,
#  'parentskidsrelationship': 1280,
#  'grandfathergrandsonrelationship': 763,
#  'paris': 1281,
#  'expensiverestaurant': 615,
#  'river': 1474,
#  'cook': 397,
#  'mouse': 1156,
#  'confidence': 389,
#  'sfamily': 1581,
#  'work': 1973,
#  'kitchen': 972,
#  'court': 412,
#  'chef': 321,
#  'himalaya': 822,
#  'martialarts': 1076,
#  'rivalry': 1473,
#  'ninja': 1219,
#  'escapade': 595,
#  'loveandromance': 1030,
#  'jealousy': 944,
#  'dance': 444,
#  'zoo': 1999,
#  'chimp': 332,
#  'penguin': 1298,
#  'volcano': 1914,
#  'zebra': 1995,
#  'shark': 1583,
#  'museum': 1166,
#  'boxer': 230,
#  'philosophy': 1307,
#  'kungfu': 977,
#  'subway': 1710,
#  'sunlight': 1719,
#  'computervirus': 384,
#  'supercomputer': 1721,
#  'virtualreality': 1909,
#  'truth': 1840,
#  'cyberpunk': 441,
#  'betrayal': 198,
#  'curse': 438,
#  'snow': 1632,
#  'troll': 1834,
#  'australia': 134,
#  'survival': 1739,
#  'ontherun': 1247,
#  'rome': 1488,
#  'vatican': 1884,
#  'christian': 336,
#  'prequel': 1377,
#  'conspiracy': 392,
#  'catholicism': 303,
#  'newmexico': 1206,
#  'kidsandfamily': 963,
#  'underworld': 1861,
#  'mythology': 1181,
#  'zeus': 1996,
#  'ancientgreece': 78,
#  'vampire': 1880,
#  'fishoutofwater': 688,
#  'madness': 1046,
#  '18thcentury': 0,
#  'austria': 135,
#  'vienna': 1895,
#  'ruralsetting': 1494,
#  'flower': 696,
#  'florist': 695,
#  'panda': 1268,
#  'ice': 872,
#  'warship': 1934,
#  'arrest': 113,
#  'spirit': 1666,
#  'berlin': 194,
#  'whitehouse': 1948,
#  'explosive': 619,
#  'mobilephone': 1130,
#  'map': 1066,
#  'mask': 1079,
#  'honeymoon': 843,
#  'letter': 991,
#  'toshootdead': 1805,
#  'video': 1891,
#  'disguise': 513,
#  'celebration': 308,
#  'goodandbad': 755,
#  'usapresident': 1876,
#  'secretservice': 1554,
#  'basedonchildren': 163,
#  'sbook': 1520,
#  'frog': 718,
#  'girlfriend': 752,
#  'intelligence': 907,
#  'adoption': 21,
#  'childprodigy': 330,
#  'growingup': 775,
#  'children': 331,
#  'dog': 524,
#  'firstlove': 683,
#  'ancientegypt': 77,
#  'trouble': 1836,
#  'adultery': 24,
#  'beauty': 189,
#  'fraud': 711,
#  'swordfight': 1750,
#  'battlefield': 182,
#  'femalefriendship': 664,
#  'asteroid': 123,
#  'spacemarine': 1656,
#  'wedding': 1942,
#  'disastermovie': 509,
#  'illegalimmigration': 877,
#  'deportation': 482,
#  'newidentity': 1203,
#  'flyingsaucer': 698,
#  'light': 999,
#  'denmark': 478,
#  'lie': 996,
#  'alienation': 51,
#  'sin': 1604,
#  'royalty': 1491,
#  'adultanimation': 23,
#  'china': 333,
#  'ancientchina': 76,
#  'nightmare': 1216,
#  'desperation': 488,
#  'hold': 831,
#  'uprobbery': 1874,
#  'suburbia': 1709,
#  'humiliation': 867,
#  'unemployment': 1862,
#  'warcrimes': 1928,
#  'swordplay': 1751,
#  'general': 739,
#  'warveteran': 1935,
#  'armsdeal': 109,
#  'emperor': 586,
#  'languagebarrier': 981,
#  'discovery': 510,
#  'mercenary': 1100,
#  'insurgence': 906,
#  'lossofhusband': 1018,
#  'slaughter': 1621,
#  'alcoholic': 48,
#  'moses': 1145,
#  'bible': 199,
#  'teleportation': 1775,
#  'spacemission': 1657,
#  'vulcan': 1920,
#  'alternatereality': 60,
#  'thanksgiving': 1785,
#  'badboss': 144,
#  'wifehusbandrelationship': 1952,
#  'sacrifice': 1499,
#  'mothersonrelationship': 1152,
#  'thief': 1793,
#  'desert': 484,
#  'massmurder': 1082,
#  'retirement': 1464,
#  'california': 268,
#  'gun': 781,
#  'mutation': 1177,
#  'psychology': 1411,
#  'anger': 83,
#  'mirror': 1120,
#  'military': 1112,
#  'terror': 1779,
#  'assassin': 119,
#  'missile': 1123,
#  'surveillance': 1738,
#  'battleassignment': 181,
#  'usa': 1875,
#  'nazis': 1194,
#  'nazigermany': 1193,
#  'perioddrama': 1301,
#  'brooklynnewyorkcity': 249,
#  'british': 246,
#  'oil': 1239,
#  'fangvamp': 643,
#  'fugitive': 720,
#  'littlegirl': 1005,
#  'cannibal': 276,
#  'rape': 1436,
#  'grizzlybear': 772,
#  'wilderness': 1953,
#  'nativeamerican': 1188,
#  'violence': 1904,
#  'basedontrueevents': 172,
#  'underdog': 1857,
#  'power': 1358,
#  'superpower': 1730,
#  'sheriff': 1585,
#  'pet': 1304,
#  'lasvegas': 983,
#  'europe': 602,
#  'prosecution': 1401,
#  'dangerous': 448,
#  'falseidentity': 632,
#  'revelation': 1466,
#  'weapon': 1939,
#  'shootout': 1591,
#  'espionage': 599,
#  'footchase': 700,
#  'darkpast': 454,
#  'flashback': 690,
#  'mentor': 1098,
#  'restaurant': 1461,
#  'shop': 1592,
#  'turtle': 1842,
#  'fighting': 673,
#  'competition': 382,
#  'factory': 624,
#  'television': 1776,
#  'propaganda': 1399,
#  'rebellion': 1441,
#  'blood': 218,
#  'femaleprotagonist': 666,
#  'danger': 447,
#  'posttraumaticstressdisorder': 1355,
#  'newjersey': 1204,
#  'miami': 1106,
#  'kukluxklan': 976,
#  'cuba': 434,
#  'mexicanstandoff': 1103,
#  'ecstasy': 574,
#  'gunfight': 783,
#  'gangster': 730,
#  'interrogation': 911,
#  'carchase': 285,
#  'druglord': 553,
#  'illegaldrugs': 876,
#  'deaagent': 459,
#  'buddycop': 257,
#  'actionhero': 13,
#  'assassination': 120,
#  'coldwar': 364,
#  'sovietunion': 1651,
#  'god': 753,
#  'reporter': 1456,
#  'dark': 449,
#  'ranch': 1434,
#  'comet': 373,
#  'prehistoric': 1370,
#  'prehistoriccreature': 1372,
#  'prehistoricadventure': 1371,
#  'prehistorictimes': 1374,
#  'date': 455,
#  'prison': 1387,
#  'fish': 685,
#  'mayor': 1088,
#  'rain': 1433,
#  'one': 1242,
#  'christmasparty': 341,
#  'halloween': 791,
#  'gold': 754,
#  'policeoperation': 1339,
#  'undead': 1853,
#  'marriageproposal': 1072,
#  'jamaica': 938,
#  'skeleton': 1615,
#  'governor': 761,
#  'caribbean': 290,
#  'resistance': 1460,
#  'game': 727,
#  'holygrail': 836,
#  'christianity': 338,
#  'monk': 1135,
#  'secretsociety': 1555,
#  'bird': 204,
#  'audition': 133,
#  'brazil': 238,
#  'fbi': 658,
#  'freedom': 712,
#  'escapefromprison': 598,
#  'carcrash': 286,
#  'policechase': 1334,
#  'escapedconvict': 597,
#  'seamonster': 1541,
#  'falselyaccused': 633,
#  'doublelife': 534,
#  'telepathy': 1774,
#  'hologram': 835,
#  'cave': 306,
#  'iraq': 924,
#  'rooftop': 1489,
#  'newlove': 1205,
#  'tornado': 1803,
#  'evacuation': 603,
#  'spain': 1662,
#  'helicopter': 808,
#  'skyscraper': 1617,
#  'ex': 609,
#  'lover': 1034,
#  'agent': 36,
#  'stormatsea': 1694,
#  'satellite': 1516,
#  'resurrection': 1462,
#  'doublecross': 533,
#  'teenageboy': 1763,
#  'cargoship': 289,
#  'mephisto': 1099,
#  'religionandsupernatural': 1452,
#  'devil': 495,
#  'ghostworld': 746,
#  'robbery': 1477,
#  'android': 81,
#  'spinoff': 1665,
#  'police': 1332,
#  'detroit': 493,
#  'lossofbrother': 1013,
#  'lovetriangle': 1037,
#  'baseball': 160,
#  'athlete': 127,
#  'airport': 43,
#  'garage': 733,
#  'explodingbuilding': 617,
#  'showdown': 1598,
#  'deathstar': 468,
#  'dreamsequence': 541,
#  'senate': 1561,
#  'investigation': 920,
#  'lasergun': 982,
#  'company': 381,
#  'friend': 715,
#  'worldwari': 1977,
#  'galaxy': 725,
#  'stoneage': 1690,
#  'cavemen': 307,
#  'olympicgames': 1241,
#  'radiotransmission': 1431,
#  'marinecorps': 1069,
#  'code': 362,
#  'van': 1882,
#  'newyorkcity': 1211,
#  'sewer': 1570,
#  'loss': 1012,
#  'smalltown': 1627,
#  'motel': 1147,
#  'cabin': 265,
#  'partnership': 1285,
#  'catastrophe': 301,
#  'telekinesis': 1773,
#  'bodyhorror': 223,
#  'nightshift': 1217,
#  'securityguard': 1557,
#  'earthquake': 570,
#  'disasterfilm': 508,
#  'secretintelligenceservice': 1549,
#  'tvstation': 1846,
#  'southernusa': 1650,
#  'lossofson': 1024,
#  'lossoffamily': 1016,
#  'passion': 1287,
#  'french': 714,
#  'gore': 757,
#  'bomb': 225,
#  'hitman': 829,
#  'marriagecrisis': 1071,
#  'job': 948,
#  'dysfunctionalmarriage': 566,
#  'dystopicfuture': 568,
#  'youngadult': 1990,
#  'ladykiller': 979,
#  'biography': 203,
#  'womanizer': 1969,
#  'congress': 390,
#  'journalist': 951,
#  'vandalism': 1883,
#  'nightclub': 1214,
#  'knife': 973,
#  'party': 1286,
#  'playboy': 1326,
#  'basedongraphicnovel': 167,
#  'handtohandcombat': 794,
#  'minions': 1117,
#  'farm': 647,
#  'cow': 416,
#  'sport': 1670,
#  'boat': 221,
#  'diamond': 498,
#  'intolerance': 915,
#  'hacker': 788,
#  'transportofprisoners': 1822,
#  'fistfight': 689,
#  'cop': 399,
#  'cellphone': 310,
#  'walkietalkie': 1923,
#  'basedonarticle': 161,
#  'fireworks': 682,
#  'transporter': 1821,
#  'cat': 299,
#  'stepfather': 1687,
#  'chicago': 322,
#  'law': 984,
#  'religious': 1453,
#  'orphanage': 1256,
#  'music': 1167,
#  'voodoo': 1916,
#  'kiss': 971,
#  'isolation': 931,
#  'science': 1530,
#  'clone': 357,
#  'transplantation': 1820,
#  'genetics': 741,
#  'cloning': 358,
#  'architect': 107,
#  'detective': 492,
#  'blackmail': 213,
#  'brother': 252,
#  'romanempire': 1485,
#  'slavery': 1623,
#  'evidence': 604,
#  'neo': 1199,
#  'noir': 1221,
#  'italy': 934,
#  'poker': 1331,
#  'casino': 296,
#  'banker': 153,
#  'torture': 1804,
#  'gorilla': 758,
#  'shotgun': 1594,
#  'mentalinstitution': 1096,
#  'hidingplace': 814,
#  'prisonguard': 1391,
#  'blackpeople': 214,
#  'drugtraffic': 555,
#  'drugsmuggle': 554,
#  'ambition': 63,
#  'policecorruption': 1335,
#  'policedetective': 1336,
#  'dishonesty': 514,
#  'florida': 694,
#  'horsebackriding': 853,
#  'in': 886,
#  'vomit': 1915,
#  'narration': 1184,
#  'shotintheshoulder': 1595,
#  'buddycomedy': 256,
#  'witness': 1961,
#  'witnessprotection': 1962,
#  'marshal': 1075,
#  'bountyhunter': 229,
#  'plantation': 1323,
#  'racism': 1427,
#  'dentist': 479,
#  'deadly': 461,
#  'chasesandraces': 317,
#  'judge': 953,
#  'religion': 1451,
#  'birthday': 205,
#  'palace': 1267,
#  'numberintitle': 1230,
#  'airplanecrash': 42,
#  'ensemblecast': 590,
#  'lying': 1043,
#  'hotel': 860,
#  'undercoveragent': 1855,
#  'sex': 1571,
#  'pastor': 1289,
#  'nudity': 1229,
#  'anti': 93,
#  'christ': 335,
#  'atheist': 126,
#  'priest': 1382,
#  'church': 343,
#  'journalism': 950,
#  'fisherman': 686,
#  'smuggling': 1629,
#  'sexuality': 1579,
#  'bank': 152,
#  'humor': 868,
#  'wallstreet': 1924,
#  'stockbroker': 1688,
#  'drug': 545,
#  'psychologist': 1410,
#  'criminal': 425,
#  'millionaire': 1113,
#  'disfigurement': 512,
#  'fatherfigure': 655,
#  'spacebattle': 1653,
#  'satire': 1517,
#  '1930s': 2,
#  'owl': 1262,
#  'sexism': 1574,
#  'basketball': 178,
#  'evilcorporation': 606,
#  'littleboy': 1004,
#  'planet': 1321,
#  'alienlife': 55,
#  'form': 705,
#  'rescuemission': 1458,
#  'fbiagent': 659,
#  'baby': 141,
#  'whale': 1945,
#  'bar': 156,
#  'mafiaboss': 1049,
#  'dialogue': 496,
#  'invention': 918,
#  'independentfilm': 890,
#  'son': 1642,
#  'irish': 927,
#  'american': 66,
#  'immigrant': 882,
#  'gangwar': 732,
#  'pig': 1313,
#  'gang': 729,
#  'surfer': 1734,
#  'worldchampion': 1976,
#  'idol': 875,
#  'mockumentary': 1132,
#  'prisonersofwar': 1390,
#  'wound': 1979,
#  'politics': 1343,
#  'politician': 1342,
#  'electioncampaign': 580,
#  'taxi': 1758,
#  'cinderella': 347,
#  'tree': 1830,
#  'lossofdaughter': 1015,
#  ...}

# %%
# generate a mapping from movie title -> index (in df)
movie2idx = pd.Series(df.index, index=df['title'])
movie2idx
# Out:
# title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4798
# Newlyweds                                   4799
# Signed, Sealed, Delivered                   4800
# Shanghai Calling                            4801
# My Date with Drew                           4802
# Length: 4803, dtype: int64

# %%
idx = movie2idx['Scream 3']
idx
# Out:
# 1164

# %%
query = X[idx]
query
# Out:
# <1x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>

# %%
# print the query vector
query.toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
# compute similarity between query and every vector in X
scores = cosine_similarity(query, X)
scores
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
# currently the array is 1 x N, make it just a 1-D array
scores = scores.flatten()

# %%
plt.plot(scores)

# %%
(-scores).argsort()
# Out:
# array([1164, 3902, 4628, ..., 1714, 1720, 4802])

# %%
plt.plot(scores[(-scores).argsort()])

# %%
# get top 5 matches
# exclude self (similarity between query and itself yields max score)
recommended_idx = (-scores).argsort()[1:6]

# %%
# convert indices back to titles
df['title'].iloc[recommended_idx]
# Out:
# 3902    Friday the 13th Part VI: Jason Lives
# 4628                          Graduation Day
# 4053        Friday the 13th: A New Beginning
# 4048                             The Calling
# 1084                         The Glimmer Man
# Name: title, dtype: object

# %%
# create a function that generates recommendations
def recommend(title):
  # get the row in the dataframe for this movie
  idx = movie2idx[title]
  if type(idx) == pd.Series:
    idx = idx.iloc[0]

  # calculate the pairwise similarities for this movie
  query = X[idx]
  scores = cosine_similarity(query, X)

  # currently the array is 1 x N, make it just a 1-D array
  scores = scores.flatten()

  # get the indexes of the highest scoring movies
  # get the first K recommendations
  # don't return itself!
  recommended_idx = (-scores).argsort()[1:6]

  # return the titles of the recommendations
  return df['title'].iloc[recommended_idx]

# %%
print("Recommendations for 'Scream 3':")
print(recommend('Scream 3'))
# Out:
# Recommendations for 'Scream 3':
# 3902    Friday the 13th Part VI: Jason Lives
# 4628                          Graduation Day
# 4053        Friday the 13th: A New Beginning
# 4048                             The Calling
# 1084                         The Glimmer Man
# Name: title, dtype: object

# %%
print("Recommendations for 'Mortal Kombat':")
print(recommend('Mortal Kombat'))
# Out:
# Recommendations for 'Mortal Kombat':
# 1611              Mortal Kombat: Annihilation
# 1670                       DOA: Dead or Alive
# 3856              In the Name of the King III
# 1001    Street Fighter: The Legend of Chun-Li
# 2237                        Alone in the Dark
# Name: title, dtype: object

# %%
print("Recommendations for 'Runaway Bride':")
print(recommend('Runaway Bride'))
# Out:
# Recommendations for 'Runaway Bride':
# 4115                    House of D
# 2325    My Big Fat Greek Wedding 2
# 4604         It Happened One Night
# 3313                  An Education
# 2689            Our Family Wedding
# Name: title, dtype: object
