# %%
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2024-03-27 04:49:30--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26622 (26K) [text/plain]
# Saving to: ‘edgar_allan_poe.txt’
#
# edgar_allan_poe.txt 100%[===================>]  26.00K  --.-KB/s    in 0.001s
#
# 2024-03-27 04:49:30 (19.7 MB/s) - ‘edgar_allan_poe.txt’ saved [26622/26622]
#
# --2024-03-27 04:49:30--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54.97K  --.-KB/s    in 0.006s
#
# 2024-03-27 04:49:30 (9.26 MB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %%
input_files = [
  'edgar_allan_poe.txt',
  'robert_frost.txt',
]

# %%
# !head edgar_allan_poe.txt
# Out:
# LO! Death hath rear'd himself a throne
# In a strange city, all alone,
# Far down within the dim west
# Where the good, and the bad, and the worst, and the best,
# Have gone to their eternal rest.
#
# There shrines, and palaces, and towers
# Are not like any thing of ours
# Oh no! O no! ours never loom
# To heaven with that ungodly gloom!

# %%
# !head robert_frost.txt
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there

# %%
# collect data into lists
input_texts = []
labels = []

for label, f in enumerate(input_files):
  print(f"{f} corresponds to label {label}")

  for line in open(f):
    line = line.rstrip().lower()
    if line:
      # remove punctuation
      line = line.translate(str.maketrans('', '', string.punctuation))

      input_texts.append(line)
      labels.append(label)
# Out:
# edgar_allan_poe.txt corresponds to label 0
# robert_frost.txt corresponds to label 1

# %%
train_text, test_text, Ytrain, Ytest = train_test_split(input_texts, labels)

# %%
len(Ytrain), len(Ytest)
# Out:
# (1615, 539)

# %%
train_text[:5]
# Out:
# ['and those will bear some keeping still about',
#  'birch boughs enough piled everywhere—',
#  'how fathomless a capacity for love',
#  'john himself wont imagine who he is',
#  'nothing would do but they must fix a day']

# %%
Ytrain[:5]
# Out:
# [1, 1, 0, 1, 1]

# %%
idx = 1
word2idx = {'<unk>': 0}

# %%
# create a word2idx dict
for text in train_text:
    tokens = text.split()
    for token in tokens:
      if token not in word2idx:
        word2idx[token] = idx
        idx += 1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'and': 1,
#  'those': 2,
#  'will': 3,
#  'bear': 4,
#  'some': 5,
#  'keeping': 6,
#  'still': 7,
#  'about': 8,
#  'birch': 9,
#  'boughs': 10,
#  'enough': 11,
#  'piled': 12,
#  'everywhere—': 13,
#  'how': 14,
#  'fathomless': 15,
#  'a': 16,
#  'capacity': 17,
#  'for': 18,
#  'love': 19,
#  'john': 20,
#  'himself': 21,
#  'wont': 22,
#  'imagine': 23,
#  'who': 24,
#  'he': 25,
#  'is': 26,
#  'nothing': 27,
#  'would': 28,
#  'do': 29,
#  'but': 30,
#  'they': 31,
#  'must': 32,
#  'fix': 33,
#  'day': 34,
#  'gets': 35,
#  'sort': 36,
#  'of': 37,
#  'bakeshop': 38,
#  'meals': 39,
#  'together': 40,
#  'if': 41,
#  'the': 42,
#  'wish': 43,
#  'hadnt': 44,
#  'been': 45,
#  'too': 46,
#  'strong': 47,
#  'in': 48,
#  'me': 49,
#  'or': 50,
#  'i': 51,
#  'cant': 52,
#  'give': 53,
#  'myself': 54,
#  'to': 55,
#  'hear': 56,
#  'voices': 57,
#  'door': 58,
#  'halted': 59,
#  'helpless': 60,
#  'on': 61,
#  'landing': 62,
#  'watch': 63,
#  'his': 64,
#  'woods': 65,
#  'fill': 66,
#  'up': 67,
#  'with': 68,
#  'snow': 69,
#  'fresh': 70,
#  'myrtle': 71,
#  'my': 72,
#  'blade': 73,
#  'ill': 74,
#  'entwine': 75,
#  'wanted': 76,
#  'try': 77,
#  'something': 78,
#  'noise': 79,
#  'want': 80,
#  'get': 81,
#  'out': 82,
#  'train': 83,
#  'go': 84,
#  'back': 85,
#  'hours': 86,
#  'daylight': 87,
#  'gather': 88,
#  'atmosphere': 89,
#  'all': 90,
#  'whom': 91,
#  'thine': 92,
#  'absence': 93,
#  'night': 94,
#  'tell': 95,
#  'her': 96,
#  'does': 97,
#  'she': 98,
#  'look': 99,
#  'like': 100,
#  'dyou': 101,
#  'know': 102,
#  'person': 103,
#  'so': 104,
#  'related': 105,
#  'herself': 106,
#  'think': 107,
#  'were': 108,
#  'mad': 109,
#  'why': 110,
#  'here': 111,
#  'from': 112,
#  'north': 113,
#  'south': 114,
#  'across': 115,
#  'blue': 116,
#  'no': 117,
#  'either': 118,
#  'hell': 119,
#  'just': 120,
#  'drop': 121,
#  'reins': 122,
#  'dont': 123,
#  'trust': 124,
#  'your': 125,
#  'eyes': 126,
#  'youve': 127,
#  'said': 128,
#  'find': 129,
#  'anyone': 130,
#  'take': 131,
#  'place': 132,
#  'early': 133,
#  'leafs': 134,
#  'flower': 135,
#  'by': 136,
#  'plain': 137,
#  'statement': 138,
#  'relationship': 139,
#  'kitchen': 140,
#  'had': 141,
#  'dark': 142,
#  'own': 143,
#  'died': 144,
#  'arms': 145,
#  'adoring': 146,
#  'airs': 147,
#  'ah': 148,
#  'we': 149,
#  'safely': 150,
#  'may': 151,
#  'its': 152,
#  'gleaming': 153,
#  'rivers': 154,
#  'glide': 155,
#  'when': 156,
#  'flew': 157,
#  'brightly': 158,
#  'have': 159,
#  'gone': 160,
#  'their': 161,
#  'eternal': 162,
#  'rest': 163,
#  'radiant': 164,
#  'palace': 165,
#  'reared': 166,
#  'head': 167,
#  'strolled': 168,
#  'thither': 169,
#  'not': 170,
#  'expecting': 171,
#  'sos': 172,
#  'everything': 173,
#  'hideous': 174,
#  'throng': 175,
#  'rush': 176,
#  'forever': 177,
#  'well': 178,
#  'now': 179,
#  'this': 180,
#  'dim': 181,
#  'lake': 182,
#  'auber': 183,
#  'nation': 184,
#  'venuses': 185,
#  'unextinguished': 186,
#  'sun': 187,
#  'thy': 188,
#  'dear': 189,
#  'name': 190,
#  'as': 191,
#  'text': 192,
#  'though': 193,
#  'bidden': 194,
#  'thee': 195,
#  'wit': 196,
#  'wisdom': 197,
#  'king': 198,
#  'upon': 199,
#  'faroff': 200,
#  'happier': 201,
#  'sea': 202,
#  'you': 203,
#  'speak': 204,
#  'that': 205,
#  'what': 206,
#  'great': 207,
#  'monolithic': 208,
#  'knees': 209,
#  'former': 210,
#  'town': 211,
#  'earthly': 212,
#  'weather': 213,
#  'made': 214,
#  'at': 215,
#  'tutelar': 216,
#  'shrine': 217,
#  'ive': 218,
#  'built': 219,
#  'big': 220,
#  'church': 221,
#  'organ': 222,
#  'one': 223,
#  'old': 224,
#  'davis': 225,
#  'bade': 226,
#  'graciously': 227,
#  'whose': 228,
#  'vast': 229,
#  'wheels': 230,
#  'could': 231,
#  'see': 232,
#  'toffile': 233,
#  'it': 234,
#  'lyre': 235,
#  'within': 236,
#  'sky': 237,
#  'hand': 238,
#  'buttonbox': 239,
#  'be': 240,
#  'there': 241,
#  'half': 242,
#  'believe': 243,
#  'wild': 244,
#  'light': 245,
#  'fraught': 246,
#  'slippery': 247,
#  'rocks': 248,
#  'beside': 249,
#  'waterfall': 250,
#  'twothousandmile': 251,
#  'coast': 252,
#  'our': 253,
#  'hens': 254,
#  'cows': 255,
#  'pigs': 256,
#  'are': 257,
#  'always': 258,
#  'better': 259,
#  'bush': 260,
#  'peas': 261,
#  'looked': 262,
#  'toward': 263,
#  'heaven': 264,
#  'against': 265,
#  'small': 266,
#  'good': 267,
#  'anything': 268,
#  'growing': 269,
#  'disturbed': 270,
#  'doubt': 271,
#  'thought': 272,
#  'nights': 273,
#  'year': 274,
#  'havent': 275,
#  'seen': 276,
#  'him': 277,
#  'strange': 278,
#  'set': 279,
#  'off': 280,
#  'clasps': 281,
#  'heart': 282,
#  'laughed': 283,
#  'bluebells': 284,
#  'gracing': 285,
#  'tunnel': 286,
#  'mouth': 287,
#  'bless': 288,
#  'isnt': 289,
#  'grandsir': 290,
#  'stark': 291,
#  'granny': 292,
#  'spirit': 293,
#  'doth': 294,
#  'dwell': 295,
#  'has': 296,
#  'tears': 297,
#  'dry': 298,
#  'wonder': 299,
#  'where': 300,
#  'oracle': 301,
#  'tending': 302,
#  'planets': 303,
#  'over': 304,
#  'got': 305,
#  'them': 306,
#  'flowers': 307,
#  'backs': 308,
#  'legitimately': 309,
#  'demand': 310,
#  'living': 311,
#  'youre': 312,
#  'hour': 313,
#  'swellings': 314,
#  'hint': 315,
#  'winds': 316,
#  'pauses': 317,
#  'sit': 318,
#  'before': 319,
#  'open': 320,
#  'most': 321,
#  'immemorial': 322,
#  'alias': 323,
#  'through': 324,
#  'presented': 325,
#  'land': 326,
#  'tide': 327,
#  'saw': 328,
#  'once': 329,
#  'only': 330,
#  'years': 331,
#  'ago': 332,
#  'dew': 333,
#  'time': 334,
#  'oer': 335,
#  'summer': 336,
#  'grass': 337,
#  'blend': 338,
#  'turrets': 339,
#  'shadows': 340,
#  'other': 341,
#  'yes': 342,
#  'two': 343,
#  'much': 344,
#  'concerned': 345,
#  'trapper': 346,
#  'looking': 347,
#  'point': 348,
#  'us': 349,
#  'path': 350,
#  'skies': 351,
#  'having': 352,
#  'witch': 353,
#  'happened': 354,
#  'seem': 355,
#  'say': 356,
#  'faintest': 357,
#  'restless': 358,
#  'rustling': 359,
#  'ran': 360,
#  'four': 361,
#  'cards': 362,
#  'yours': 363,
#  'three': 364,
#  'mine': 365,
#  'each': 366,
#  'branch': 367,
#  'interfered': 368,
#  'huse': 369,
#  'business': 370,
#  'drawn': 371,
#  'into': 372,
#  'cellar': 373,
#  'hole': 374,
#  'gentlest': 375,
#  'gentle': 376,
#  'names': 377,
#  'dost': 378,
#  'was': 379,
#  'girl': 380,
#  'way': 381,
#  'hed': 382,
#  'more': 383,
#  'because': 384,
#  'likes': 385,
#  'come': 386,
#  'straight': 387,
#  'down': 388,
#  'mountain': 389,
#  'fast': 390,
#  'sovereignty': 391,
#  'than': 392,
#  'ancient': 393,
#  'lore': 394,
#  'misty': 395,
#  'mid': 396,
#  'region': 397,
#  'weir': 398,
#  'merrily': 399,
#  'live': 400,
#  'long': 401,
#  'any': 402,
#  'comfort': 403,
#  'can': 404,
#  'sew': 405,
#  'tried': 406,
#  'improve': 407,
#  'sailing': 408,
#  'tile': 409,
#  'son': 410,
#  'grave': 411,
#  'im': 412,
#  'getting': 413,
#  'size': 414,
#  'threw': 415,
#  'wide': 416,
#  'didnt': 417,
#  'enter': 418,
#  'clad': 419,
#  'white': 420,
#  'violet': 421,
#  'bank': 422,
#  'such': 423,
#  'few': 424,
#  'people': 425,
#  'spend': 426,
#  'outdoors': 427,
#  'luminous': 428,
#  'windows': 429,
#  'boring': 430,
#  'climbing': 431,
#  'morn': 432,
#  'noon': 433,
#  'twilight': 434,
#  'suffice': 435,
#  'upper': 436,
#  'shelf': 437,
#  'tin': 438,
#  'box': 439,
#  'thats': 440,
#  'shall': 441,
#  'meet': 442,
#  'again': 443,
#  'stranger': 444,
#  'cousins': 445,
#  'family': 446,
#  'tree': 447,
#  'fell': 448,
#  'upturnd': 449,
#  'faces': 450,
#  'roses': 451,
#  'throw': 452,
#  'picture': 453,
#  'screen': 454,
#  'resemble': 455,
#  'ours': 456,
#  'soon': 457,
#  'satisfied': 458,
#  'being': 459,
#  'leave': 460,
#  'tatters': 461,
#  'hung': 462,
#  'barb': 463,
#  'thorn': 464,
#  'mockery': 465,
#  'boast': 466,
#  'very': 467,
#  'odors': 468,
#  'lips': 469,
#  'melody': 470,
#  'hearts': 471,
#  'passion': 472,
#  'tone': 473,
#  'harmless': 474,
#  'mother': 475,
#  'hears': 476,
#  'then': 477,
#  'bid': 478,
#  'sound': 479,
#  'cut': 480,
#  'demon': 481,
#  'tempted': 482,
#  'loves': 483,
#  'grownup': 484,
#  'god': 485,
#  'came': 486,
#  'sailed': 487,
#  'lot': 488,
#  'begin': 489,
#  'shed': 490,
#  'stop': 491,
#  'excuse': 492,
#  'ask': 493,
#  'window': 494,
#  'nor': 495,
#  'need': 496,
#  'mind': 497,
#  'serial': 498,
#  'ordeal': 499,
#  'scurf': 500,
#  'plants': 501,
#  'weary': 502,
#  'overheated': 503,
#  'unless': 504,
#  'done': 505,
#  'hellforleather': 506,
#  'loveless': 507,
#  'birds': 508,
#  'flock': 509,
#  'winter': 510,
#  'friends': 511,
#  'bet': 512,
#  'cribber': 513,
#  'gnawed': 514,
#  'money': 515,
#  'goes': 516,
#  'hath': 517,
#  'dwelt': 518,
#  'blotting': 519,
#  'utterly': 520,
#  'high': 521,
#  'receipted': 522,
#  'cock': 523,
#  'yard': 524,
#  'hardly': 525,
#  'breathe': 526,
#  'west': 527,
#  'makes': 528,
#  'cast': 529,
#  'both': 530,
#  'turns': 531,
#  'rare': 532,
#  'song': 533,
#  'let': 534,
#  'consideration': 535,
#  'left': 536,
#  'storm': 537,
#  'oh': 538,
#  'hasten': 539,
#  'linger': 540,
#  'banking': 541,
#  'trade': 542,
#  'leases': 543,
#  'furniture': 544,
#  'suddenly': 545,
#  'without': 546,
#  'jerk': 547,
#  'twitch': 548,
#  'another': 549,
#  'bedroom': 550,
#  'attic': 551,
#  'little': 552,
#  'cupboard': 553,
#  'achilles': 554,
#  'diomed': 555,
#  'according': 556,
#  'feared': 557,
#  'risk': 558,
#  'cannot': 559,
#  'guide': 560,
#  'aright': 561,
#  'sacred': 562,
#  'sill': 563,
#  'poetess': 564,
#  'wrote': 565,
#  'book': 566,
#  'verses': 567,
#  'pride': 568,
#  'intellectuality': 569,
#  'theyve': 570,
#  'dragged': 571,
#  'law': 572,
#  'courts': 573,
#  'signify': 574,
#  'donkeys': 575,
#  'cars': 576,
#  'bottle': 577,
#  'bad': 578,
#  'worst': 579,
#  'best': 580,
#  'poor': 581,
#  'legended': 582,
#  'tomb': 583,
#  'fairylike': 584,
#  'floats': 585,
#  'steeple': 586,
#  'runs': 587,
#  'unbridled': 588,
#  'course': 589,
#  'height': 590,
#  'adventure': 591,
#  'wampum': 592,
#  'call': 593,
#  'complain': 594,
#  'studying': 595,
#  'genealogy': 596,
#  'alas': 597,
#  'magical': 598,
#  'sad': 599,
#  'id': 600,
#  'hitched': 601,
#  'unblanketed': 602,
#  'life': 603,
#  'common': 604,
#  'which': 605,
#  'lie': 606,
#  'office': 607,
#  'illumine': 608,
#  'enkindle': 609,
#  'holy': 610,
#  'rays': 611,
#  'rapid': 612,
#  'pleiads': 613,
#  'even': 614,
#  'stardials': 615,
#  'pointed': 616,
#  'shatter': 617,
#  'inward': 618,
#  'unswept': 619,
#  'floors': 620,
#  'fingerpieces': 621,
#  'slid': 622,
#  'directions': 623,
#  'sulphurous': 624,
#  'currents': 625,
#  'yaanek': 626,
#  'well—i—be—': 627,
#  'wed': 628,
#  'ever': 629,
#  'fifteen': 630,
#  'agony': 631,
#  'sobbed': 632,
#  'letting': 633,
#  'sink': 634,
#  'took': 635,
#  'less': 636,
#  'traveled': 637,
#  'never': 638,
#  'yet': 639,
#  'voice': 640,
#  'mute': 641,
#  'plowed': 642,
#  'ground': 643,
#  'cold': 644,
#  'digger': 645,
#  'likeness': 646,
#  'surprise': 647,
#  'thrilly': 648,
#  'tourist': 649,
#  'matter': 650,
#  'far': 651,
#  'many': 652,
#  'times': 653,
#  'sign': 654,
#  'spose': 655,
#  'mallice': 656,
#  'aknown': 657,
#  'young': 658,
#  'these': 659,
#  'weak': 660,
#  'lines': 661,
#  'written': 662,
#  'ought': 663,
#  'rain': 664,
#  'sometime': 665,
#  'make': 666,
#  'free': 667,
#  'kick': 668,
#  'folks': 669,
#  'bow': 670,
#  'front': 671,
#  'hall': 672,
#  'olden': 673,
#  'dialect': 674,
#  'bird': 675,
#  'singing': 676,
#  'miraculous': 677,
#  'crescent': 678,
#  'eat': 679,
#  'barrel': 680,
#  'taken': 681,
#  'thus': 682,
#  'am': 683,
#  'passer': 684,
#  'pause': 685,
#  'gardengate': 686,
#  'broken': 687,
#  'blow': 688,
#  'mica': 689,
#  'sheets': 690,
#  'plateglass': 691,
#  'every': 692,
#  'fold': 693,
#  'between': 694,
#  'frozen': 695,
#  'lonesome': 696,
#  'october': 697,
#  'trembling': 698,
#  'wire': 699,
#  'luminary': 700,
#  'clock': 701,
#  'past': 702,
#  'stars': 703,
#  'lion': 704,
#  'ears': 705,
#  'suggest': 706,
#  'shake': 707,
#  'leaves': 708,
#  'crisped': 709,
#  'sere': 710,
#  'boys': 711,
#  'hunters': 712,
#  'known': 713,
#  't': 714,
#  'awake': 715,
#  'tis': 716,
#  'symbol': 717,
#  'token': 718,
#  'neck': 719,
#  'spare': 720,
#  'clothes': 721,
#  'pacified': 722,
#  'psyche': 723,
#  'kissed': 724,
#  'spoke': 725,
#  'lets': 726,
#  'trap': 727,
#  'an': 728,
#  'skiff': 729,
#  'spoiled': 730,
#  'began': 731,
#  'uncertain': 732,
#  'silent': 733,
#  'streams': 734,
#  'sleep': 735,
#  'dream': 736,
#  'till': 737,
#  'vacuum': 738,
#  'filmy': 739,
#  'idols': 740,
#  'diamond': 741,
#  'eye': 742,
#  'signals': 743,
#  'hourly': 744,
#  'hope': 745,
#  'above': 746,
#  'memories': 747,
#  'houses': 748,
#  'street': 749,
#  'house': 750,
#  'desperate': 751,
#  'energy': 752,
#  'beaten': 753,
#  'heed': 754,
#  'desolate': 755,
#  'appear': 756,
#  'standing': 757,
#  'put': 758,
#  'slightly': 759,
#  'sinking': 760,
#  'dull': 761,
#  'theres': 762,
#  'harm': 763,
#  'lupine': 764,
#  'sand': 765,
#  'drouth': 766,
#  'man': 767,
#  'beasts': 768,
#  'sake': 769,
#  'quickening': 770,
#  'spell': 771,
#  'pass': 772,
#  'might': 773,
#  'sing': 774,
#  'wildly': 775,
#  'cloud': 776,
#  'smoke': 777,
#  'bowed': 778,
#  'grace': 779,
#  'natural': 780,
#  'walked': 781,
#  'alone': 782,
#  'sunday': 783,
#  'after': 784,
#  'detail': 785,
#  'burned': 786,
#  'dissolved': 787,
#  'perish': 788,
#  'twice': 789,
#  'turn': 790,
#  'round': 791,
#  'saying': 792,
#  'things': 793,
#  'else': 794,
#  'idleness': 795,
#  'lovely': 796,
#  'deep': 797,
#  'strangeness': 798,
#  'chimneys': 799,
#  'false': 800,
#  'eddy': 801,
#  'toppling': 802,
#  'perhaps': 803,
#  'claim': 804,
#  'libation': 805,
#  'tyrannys': 806,
#  'blood': 807,
#  'merely': 808,
#  'wrought': 809,
#  'coming': 810,
#  'ryans': 811,
#  'hill': 812,
#  'twas': 813,
#  'worse': 814,
#  'blind': 815,
#  'beloved': 816,
#  'amid': 817,
#  'earnest': 818,
#  'woes': 819,
#  'wherever': 820,
#  'low': 821,
#  'wet': 822,
#  'turrettops': 823,
#  'given': 824,
#  'softmurmured': 825,
#  'words': 826,
#  'fulfilled': 827,
#  'age': 828,
#  'beneath': 829,
#  'tamarind': 830,
#  'outwalked': 831,
#  'furthest': 832,
#  'city': 833,
#  'blushed': 834,
#  'bloomed': 835,
#  'fever': 836,
#  'minute': 837,
#  'showed': 838,
#  'arthur': 839,
#  'amy': 840,
#  'signs': 841,
#  'ceasing': 842,
#  'hymns': 843,
#  'attend': 844,
#  'faith': 845,
#  'godliness': 846,
#  'throne': 847,
#  'playhouse': 848,
#  'bare': 849,
#  'legs': 850,
#  'bed': 851,
#  'leak': 852,
#  'emptied': 853,
#  'forty': 854,
#  'wilds': 855,
#  'mountains': 856,
#  'intense': 857,
#  'storms': 858,
#  'fate': 859,
#  'oercast': 860,
#  'garden': 861,
#  'hate': 862,
#  'gave': 863,
#  'beyond': 864,
#  'shattered': 865,
#  'seedpod': 866,
#  'monarch': 867,
#  'thoughts': 868,
#  'dominion': 869,
#  'whence': 870,
#  'forth': 871,
#  'sometimes': 872,
#  'authority': 873,
#  'doesnt': 874,
#  'pocket': 875,
#  'resurrection': 876,
#  'deepburied': 877,
#  'leaf': 878,
#  'lingered': 879,
#  'brown': 880,
#  'crib': 881,
#  'slept': 882,
#  'sures': 883,
#  'born': 884,
#  'lurid': 885,
#  'river': 886,
#  'road': 887,
#  'greenest': 888,
#  'valleys': 889,
#  'communing': 890,
#  'angels': 891,
#  'wheres': 892,
#  'beauty': 893,
#  'birth': 894,
#  'wasnt': 895,
#  'warn': 896,
#  'misting': 897,
#  'fair': 898,
#  'however': 899,
#  'books': 900,
#  'rid': 901,
#  'start': 902,
#  'lately': 903,
#  'apathy': 904,
#  'art': 905,
#  'mean': 906,
#  'listened': 907,
#  'among': 908,
#  'sounds': 909,
#  'inscription': 910,
#  'wall': 911,
#  'wander': 912,
#  'ways': 913,
#  'incredulous': 914,
#  'luck': 915,
#  'shudder': 916,
#  'notes': 917,
#  'bones': 918,
#  'knew': 919,
#  'reason': 920,
#  'hawks': 921,
#  'since': 922,
#  'chickentime': 923,
#  'anyway': 924,
#  'tells': 925,
#  'brought': 926,
#  'home': 927,
#  'publisher': 928,
#  'seek': 929,
#  'treasure': 930,
#  'jewelled': 931,
#  'nebulous': 932,
#  'lustre': 933,
#  'moonbeam': 934,
#  'hangs': 935,
#  'beaded': 936,
#  'fur': 937,
#  'spin': 938,
#  'return': 939,
#  'lovelight': 940,
#  'marry': 941,
#  'hast': 942,
#  'thou': 943,
#  'torn': 944,
#  'naiad': 945,
#  'flood': 946,
#  'claiming': 947,
#  'priority': 948,
#  'starkness': 949,
#  'yankees': 950,
#  'owe': 951,
#  'gratitude': 952,
#  'melancholy': 953,
#  'waters': 954,
#  'alley': 955,
#  'titanic': 956,
#  'last': 957,
#  'hesperides': 958,
#  'geese': 959,
#  'united': 960,
#  'strengths': 961,
#  'withering': 962,
#  'truly': 963,
#  'men': 964,
#  'earth': 965,
#  'stay': 966,
#  'liked': 967,
#  'ten': 968,
#  'million': 969,
#  'silver': 970,
#  'lizards': 971,
#  'push': 972,
#  'headboard': 973,
#  'tall': 974,
#  'sincere': 975,
#  'reply': 976,
#  'stairs': 977,
#  'footsteps': 978,
#  'step': 979,
#  'state': 980,
#  'glory': 981,
#  'befitting': 982,
#  'published': 983,
#  'starry': 984,
#  'choir': 985,
#  'hes': 986,
#  'dropped': 987,
#  'child': 988,
#  'traveler': 989,
#  'stood': 990,
#  'palsied': 991,
#  'also': 992,
#  'sorrow': 993,
#  'speaking': 994,
#  'dunnow': 995,
#  'under': 996,
#  'shelter': 997,
#  'happen': 998,
#  'prefer': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2525

# %%
# convert data into integer format
train_text_int = []
test_text_int = []

for text in train_text:
  tokens = text.split()
  line_as_int = [word2idx[token] for token in tokens]
  train_text_int.append(line_as_int)

for text in test_text:
  tokens = text.split()
  line_as_int = [word2idx.get(token, 0) for token in tokens]
  test_text_int.append(line_as_int)

# %%
train_text_int[100:105]
# Out:
# [[410, 149, 107, 31, 141, 16, 411, 388, 48, 42, 373],
#  [412, 413, 46, 224, 18, 72, 414, 51, 95, 306],
#  [20, 415, 42, 58, 416, 30, 25, 417, 418],
#  [419, 90, 48, 420, 199, 16, 421, 422],
#  [1, 423, 424, 425]]

# %%
# initialize A and pi matrices - for both classes
V = len(word2idx)

A0 = np.ones((V, V))
pi0 = np.ones(V)

A1 = np.ones((V, V))
pi1 = np.ones(V)

# %%
# compute counts for A and pi
def compute_counts(text_as_int, A, pi):
  for tokens in text_as_int:
    last_idx = None
    for idx in tokens:
      if last_idx is None:
        # it's the first word in a sentence
        pi[idx] += 1
      else:
        # the last word exists, so count a transition
        A[last_idx, idx] += 1

      # update last idx
      last_idx = idx


compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 0], A0, pi0)
compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 1], A1, pi1)

# %%
# normalize A and pi so they are valid probability matrices
# convince yourself that this is equivalent to the formulas shown before
A0 /= A0.sum(axis=1, keepdims=True)
pi0 /= pi0.sum()

A1 /= A1.sum(axis=1, keepdims=True)
pi1 /= pi1.sum()

# %%
# log A and pi since we don't need the actual probs
logA0 = np.log(A0)
logpi0 = np.log(pi0)

logA1 = np.log(A1)
logpi1 = np.log(pi1)

# %%
# compute priors
count0 = sum(y == 0 for y in Ytrain)
count1 = sum(y == 1 for y in Ytrain)
total = len(Ytrain)
p0 = count0 / total
p1 = count1 / total
logp0 = np.log(p0)
logp1 = np.log(p1)
p0, p1
# Out:
# (0.3411764705882353, 0.6588235294117647)

# %%
# build a classifier
class Classifier:
  def __init__(self, logAs, logpis, logpriors):
    self.logAs = logAs
    self.logpis = logpis
    self.logpriors = logpriors
    self.K = len(logpriors) # number of classes

  def _compute_log_likelihood(self, input_, class_):
    logA = self.logAs[class_]
    logpi = self.logpis[class_]

    last_idx = None
    logprob = 0
    for idx in input_:
      if last_idx is None:
        # it's the first token
        logprob += logpi[idx]
      else:
        logprob += logA[last_idx, idx]

      # update last_idx
      last_idx = idx

    return logprob

  def predict(self, inputs):
    predictions = np.zeros(len(inputs))
    for i, input_ in enumerate(inputs):
      posteriors = [self._compute_log_likelihood(input_, c) + self.logpriors[c] for c in range(self.K)]
      pred = np.argmax(posteriors)
      predictions[i] = pred
    return predictions

# %%
# each array must be in order since classes are assumed to index these lists
clf = Classifier([logA0, logA1], [logpi0, logpi1], [logp0, logp1])

# %%
Ptrain = clf.predict(train_text_int)
print(f"Train acc: {np.mean(Ptrain == Ytrain)}")
# Out:
# Train acc: 0.9956656346749226

# %%
Ptest = clf.predict(test_text_int)
print(f"Test acc: {np.mean(Ptest == Ytest)}")
# Out:
# Test acc: 0.8608534322820037

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
cm = confusion_matrix(Ytrain, Ptrain)
cm
# Out:
# array([[ 544,    7],
#        [   0, 1064]])

# %%
cm_test = confusion_matrix(Ytest, Ptest)
cm_test
# Out:
# array([[104,  63],
#        [ 12, 360]])

# %%
f1_score(Ytrain, Ptrain)
# Out:
# 0.9967213114754099

# %%
f1_score(Ytest, Ptest)
# Out:
# 0.9056603773584906
