# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# --2024-05-14 09:42:01--  https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5085081 (4.8M) [text/csv]
# Saving to: ‘bbc_text_cls.csv’
#
# bbc_text_cls.csv    100%[===================>]   4.85M  16.0MB/s    in 0.3s
#
# 2024-05-14 09:42:01 (16.0 MB/s) - ‘bbc_text_cls.csv’ saved [5085081/5085081]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Embedding
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
df = pd.read_csv('bbc_text_cls.csv')

# %%
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
df['targets'] = df['labels'].astype("category").cat.codes

# %%
# number of classes
K = df['targets'].max() + 1
K
# Out:
# 5

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
# Convert sentences to sequences
MAX_VOCAB_SIZE = 2000
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(df_train['text'])
sequences_train = tokenizer.texts_to_sequences(df_train['text'])
sequences_test = tokenizer.texts_to_sequences(df_test['text'])

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
V = len(word2idx)
print('Found %s unique tokens.' % V)
# Out:
# Found 27856 unique tokens.

# %%
# pad sequences so that we get a N x T matrix
data_train = pad_sequences(sequences_train)
print('Shape of data train tensor:', data_train.shape)

# get sequence length
T = data_train.shape[1]
# Out:
# Shape of data train tensor: (1557, 3483)

# %%
data_test = pad_sequences(sequences_test, maxlen=T)
print('Shape of data test tensor:', data_test.shape)
# Out:
# Shape of data test tensor: (668, 3483)

# %%
# Create the model

# We get to choose embedding dimensionality
D = 20

# Note: we actually want to the size of the embedding to (V + 1) x D,
# because the first index starts from 1 and not 0.
# Thus, if the final index of the embedding matrix is V,
# then it actually must have size V + 1.

i = Input(shape=(T,))
x = Embedding(V + 1, D)(i)
x = LSTM(32, return_sequences=True)(x)
x = GlobalMaxPooling1D()(x)
x = Dense(K)(x)

model = Model(i, x)

# %%
# Compile and fit
model.compile(
  loss=SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)


print('Training model...')
r = model.fit(
  data_train,
  df_train['targets'],
  epochs=50,
  validation_data=(data_test, df_test['targets'])
)
# Out:
# Training model...
# Epoch 1/50
# 49/49 [==============================] - 17s 282ms/step - loss: 1.5977 - accuracy: 0.2524 - val_loss: 1.5959 - val_accuracy: 0.3024
# Epoch 2/50
# 49/49 [==============================] - 12s 245ms/step - loss: 1.5467 - accuracy: 0.3950 - val_loss: 1.4637 - val_accuracy: 0.4027
# Epoch 3/50
# 49/49 [==============================] - 19s 374ms/step - loss: 1.3949 - accuracy: 0.4457 - val_loss: 1.2859 - val_accuracy: 0.4820
# Epoch 4/50
# 49/49 [==============================] - 11s 212ms/step - loss: 1.1158 - accuracy: 0.4836 - val_loss: 0.9923 - val_accuracy: 0.5778
# Epoch 5/50
# Epoch 24/50
# 49/49 [==============================] - 7s 135ms/step - loss: 0.0372 - accuracy: 0.9949 - val_loss: 0.2206 - val_accuracy: 0.9356
# Epoch 25/50
# 49/49 [==============================] - 6s 114ms/step - loss: 0.0304 - accuracy: 0.9968 - val_loss: 0.2127 - val_accuracy: 0.9401
# Epoch 26/50
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0261 - accuracy: 0.9987 - val_loss: 0.2263 - val_accuracy: 0.9326
# Epoch 27/50
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0225 - accuracy: 0.9987 - val_loss: 0.2235 - val_accuracy: 0.9371
# Epoch 28/50
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0199 - accuracy: 0.9994 - val_loss: 0.2332 - val_accuracy: 0.9311
# Epoch 29/50
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0171 - accuracy: 0.9994 - val_loss: 0.2463 - val_accuracy: 0.9326
# Epoch 30/50
# 49/49 [==============================] - 5s 95ms/step - loss: 0.0149 - accuracy: 0.9994 - val_loss: 0.2516 - val_accuracy: 0.9341
# Epoch 31/50
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0134 - accuracy: 0.9994 - val_loss: 0.2588 - val_accuracy: 0.9356
# Epoch 32/50
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0119 - accuracy: 0.9994 - val_loss: 0.2776 - val_accuracy: 0.9311
# Epoch 33/50
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0223 - accuracy: 0.9949 - val_loss: 0.2260 - val_accuracy: 0.9431
# Epoch 34/50
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0227 - accuracy: 0.9949 - val_loss: 0.2567 - val_accuracy: 0.9192
# Epoch 35/50
# 49/49 [==============================] - 5s 102ms/step - loss: 0.0296 - accuracy: 0.9974 - val_loss: 0.1708 - val_accuracy: 0.9506
# Epoch 36/50
# 49/49 [==============================] - 6s 120ms/step - loss: 0.0189 - accuracy: 0.9987 - val_loss: 0.1639 - val_accuracy: 0.9536
# Epoch 37/50
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0631 - accuracy: 0.9833 - val_loss: 0.1956 - val_accuracy: 0.9446
# Epoch 38/50
# 49/49 [==============================] - 6s 115ms/step - loss: 0.0392 - accuracy: 0.9942 - val_loss: 0.1448 - val_accuracy: 0.9536
# Epoch 39/50
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0165 - accuracy: 0.9994 - val_loss: 0.1438 - val_accuracy: 0.9551
# Epoch 40/50
# 49/49 [==============================] - 5s 98ms/step - loss: 0.0119 - accuracy: 0.9994 - val_loss: 0.1478 - val_accuracy: 0.9581
# Epoch 41/50
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0096 - accuracy: 0.9994 - val_loss: 0.1495 - val_accuracy: 0.9566
# Epoch 42/50
# 49/49 [==============================] - 5s 96ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.1537 - val_accuracy: 0.9536
# Epoch 43/50
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.1526 - val_accuracy: 0.9551
# Epoch 44/50
# 49/49 [==============================] - 5s 99ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9566
# Epoch 45/50
# 49/49 [==============================] - 6s 116ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9566
# Epoch 46/50
# 49/49 [==============================] - 7s 137ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9566
# Epoch 47/50
# 49/49 [==============================] - 5s 108ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9581
# Epoch 48/50
# 49/49 [==============================] - 6s 115ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9611
# Epoch 49/50
# 49/49 [==============================] - 5s 106ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9596
# Epoch 50/50
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9656

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();
