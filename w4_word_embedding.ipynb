# %%
# Slower but always guaranteed to work
# !wget -nc https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Out:
# --2024-03-12 10:38:14--  https://archive.org/download/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia801203.us.archive.org/18/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz [following]
# --2024-03-12 10:38:16--  https://ia801203.us.archive.org/18/items/google-news-vectors-negative-300.bin_202311/GoogleNews-vectors-negative300.bin.gz
# Resolving ia801203.us.archive.org (ia801203.us.archive.org)... 207.241.228.23
# Connecting to ia801203.us.archive.org (ia801203.us.archive.org)|207.241.228.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/octet-stream]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G   263KB/s    in 70m 3s
#
# 2024-03-12 11:48:19 (383 KB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz

# %%
from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load_word2vec_format(
  'GoogleNews-vectors-negative300.bin',
  binary=True
)

# %%
def find_analogies(w1, w2, w3):
  # w1 - w2 = ? - w3
  # e.g. king - man = ? - woman
  #      ? = +king +woman -man
  r = word_vectors.most_similar(positive=[w1, w3], negative=[w2])
  print("%s - %s = %s - %s" % (w1, w2, r[0][0], w3))

# %%
find_analogies('king', 'man', 'woman')
# Out:
# king - man = queen - woman

# %%
find_analogies('france', 'paris', 'london')
# Out:
# france - paris = england - london

# %%
find_analogies('france', 'paris', 'rome')
# Out:
# france - paris = italy - rome

# %%
find_analogies('paris', 'france', 'italy')
# Out:
# paris - france = lohan - italy

# %%
find_analogies('france', 'french', 'english')
# Out:
# france - french = england - english

# %%
find_analogies('japan', 'japanese', 'chinese')
# Out:
# japan - japanese = tibet - chinese

# %%
find_analogies('japan', 'japanese', 'italian')
# Out:
# japan - japanese = italy - italian

# %%
find_analogies('december', 'november', 'june')
# Out:
# december - november = september - june

# %%
find_analogies('miami', 'florida', 'texas')
# Out:
# miami - florida = dallas - texas

# %%
find_analogies('einstein', 'scientist', 'painter')
# Out:
# einstein - scientist = jude - painter

# %%
find_analogies('man', 'woman', 'she')
# Out:
# man - woman = he - she

# %%
find_analogies('man', 'woman', 'aunt')
# Out:
# man - woman = uncle - aunt

# %%
find_analogies('man', 'woman', 'sister')
# Out:
# man - woman = brother - sister

# %%
find_analogies('man', 'woman', 'wife')
# Out:
# man - woman = son - wife

# %%
find_analogies('man', 'woman', 'actress')
# Out:
# man - woman = actor - actress

# %%
find_analogies('man', 'woman', 'mother')
# Out:
# man - woman = father - mother

# %%
find_analogies('nephew', 'niece', 'aunt')
# Out:
# nephew - niece = uncle - aunt

# %%
def nearest_neighbors(w):
  r = word_vectors.most_similar(positive=[w])
  print("neighbors of: %s" % w)
  for word, score in r:
    print("\t%s" % word)

# %%
nearest_neighbors('king')
# Out:
# neighbors of: king
# 	kings
# 	queen
# 	monarch
# 	crown_prince
# 	prince
# 	sultan
# 	ruler
# 	princes
# 	Prince_Paras
# 	throne

# %%
nearest_neighbors('france')
# Out:
# neighbors of: france
# 	spain
# 	french
# 	germany
# 	europe
# 	italy
# 	england
# 	european
# 	belgium
# 	usa
# 	serbia

# %%
nearest_neighbors('japan')
# Out:
# neighbors of: japan
# 	japanese
# 	tokyo
# 	america
# 	europe
# 	germany
# 	chinese
# 	india
# 	hawaii
# 	usa
# 	korea

# %%
nearest_neighbors('einstein')
# Out:
# neighbors of: einstein
# 	nikki
# 	lmfao
# 	albert
# 	armstrong
# 	joan
# 	becky
# 	mcmahon
# 	conrad
# 	lori
# 	haley

# %%
nearest_neighbors('woman')
# Out:
# neighbors of: woman
# 	man
# 	girl
# 	teenage_girl
# 	teenager
# 	lady
# 	teenaged_girl
# 	mother
# 	policewoman
# 	boy
# 	Woman

# %%
nearest_neighbors('nephew')
# Out:
# neighbors of: nephew
# 	son
# 	uncle
# 	brother
# 	grandson
# 	cousin
# 	father
# 	niece
# 	younger_brother
# 	nephews
# 	stepson

# %%
nearest_neighbors('february')
# Out:
# neighbors of: february
# 	january
# 	april
# 	september
# 	december
# 	july
# 	october
# 	november
# 	june
# 	feb
# 	norway

# %%
# Exercise: download pretrained GloVe vectors from
# https://nlp.stanford.edu/projects/glove/
#
# Implement your own find_analogies() and nearest_neighbors()
#
# Hint: you do NOT have to go hunting around on Stackoverflow
#       you do NOT have to copy and paste code from anywhere
#       look at the file you downloaded
