# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# --2024-05-07 09:21:04--  https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3421431 (3.3M) [text/csv]
# Saving to: ‘AirlineTweets.csv’
#
# AirlineTweets.csv   100%[===================>]   3.26M  --.-KB/s    in 0.04s
#
# 2024-05-07 09:21:04 (72.6 MB/s) - ‘AirlineTweets.csv’ saved [3421431/3421431]

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(0)
tf.random.set_seed(0)

# %%
df = pd.read_csv('AirlineTweets.csv')

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df[['airline_sentiment', 'text']]

# %%
df['airline_sentiment'].hist()
# Out:
# <Axes: >

# %%
df = df[df['airline_sentiment'] != 'neutral'].copy()

# %%
target_map = {'positive': 1, 'negative': 0}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df.head()
# Out:
#   airline_sentiment                                               text  target
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0
# 5          negative  @VirginAmerica seriously would pay $30 a fligh...       0
# 6          positive  @VirginAmerica yes, nearly every time I fly VX...       1

# %%
df_train, df_test = train_test_split(df, random_state=42)

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])

# %%
# data must not be sparse matrix before passing into tensorflow
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
Y_train = df_train['target']
Y_test = df_test['target']

# %%
# input dimensions
D = X_train.shape[1]

# %%
# build model
i = Input(shape=(D,))
x = Dense(1)(i) # sigmoid included in loss

model = Model(i, x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2000)]            0
#
#  dense (Dense)               (None, 1)                 2001
#
# =================================================================
# Total params: 2001 (7.82 KB)
# Trainable params: 2001 (7.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
  loss=BinaryCrossentropy(from_logits=True),
  optimizer=Adam(learning_rate=0.01),
  metrics=['accuracy']
)

# %%
r = model.fit(
  X_train, Y_train,
  validation_data=(X_test, Y_test),
  epochs=40,
  batch_size=128,
)
# Out:
# Epoch 1/40
# 68/68 [==============================] - 5s 14ms/step - loss: 0.5014 - accuracy: 0.7920 - val_loss: 0.3967 - val_accuracy: 0.8049
# Epoch 2/40
# 68/68 [==============================] - 1s 8ms/step - loss: 0.3748 - accuracy: 0.7976 - val_loss: 0.3390 - val_accuracy: 0.8226
# Epoch 3/40
# 68/68 [==============================] - 1s 8ms/step - loss: 0.3215 - accuracy: 0.8192 - val_loss: 0.3026 - val_accuracy: 0.8413
# Epoch 4/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.2844 - accuracy: 0.8455 - val_loss: 0.2769 - val_accuracy: 0.8597
# Epoch 5/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.2571 - accuracy: 0.8644 - val_loss: 0.2583 - val_accuracy: 0.8773
# Epoch 6/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.2364 - accuracy: 0.8810 - val_loss: 0.2446 - val_accuracy: 0.8888
# Epoch 7/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.2199 - accuracy: 0.8930 - val_loss: 0.2339 - val_accuracy: 0.8992
# Epoch 8/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.2065 - accuracy: 0.9033 - val_loss: 0.2250 - val_accuracy: 0.9044
# Epoch 9/40
# 68/68 [==============================] - 1s 8ms/step - loss: 0.1954 - accuracy: 0.9101 - val_loss: 0.2184 - val_accuracy: 0.9078
# Epoch 10/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1859 - accuracy: 0.9145 - val_loss: 0.2130 - val_accuracy: 0.9103
# Epoch 11/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1776 - accuracy: 0.9200 - val_loss: 0.2084 - val_accuracy: 0.9137
# Epoch 12/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1705 - accuracy: 0.9247 - val_loss: 0.2048 - val_accuracy: 0.9151
# Epoch 13/40
# 68/68 [==============================] - 1s 11ms/step - loss: 0.1641 - accuracy: 0.9271 - val_loss: 0.2019 - val_accuracy: 0.9179
# Epoch 14/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1584 - accuracy: 0.9304 - val_loss: 0.1993 - val_accuracy: 0.9186
# Epoch 15/40
# 68/68 [==============================] - 1s 12ms/step - loss: 0.1534 - accuracy: 0.9337 - val_loss: 0.1972 - val_accuracy: 0.9189
# Epoch 16/40
# 68/68 [==============================] - 1s 12ms/step - loss: 0.1486 - accuracy: 0.9361 - val_loss: 0.1955 - val_accuracy: 0.9207
# Epoch 17/40
# 68/68 [==============================] - 1s 15ms/step - loss: 0.1444 - accuracy: 0.9391 - val_loss: 0.1941 - val_accuracy: 0.9203
# Epoch 18/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1405 - accuracy: 0.9415 - val_loss: 0.1928 - val_accuracy: 0.9203
# Epoch 19/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1369 - accuracy: 0.9423 - val_loss: 0.1918 - val_accuracy: 0.9213
# Epoch 20/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1336 - accuracy: 0.9433 - val_loss: 0.1910 - val_accuracy: 0.9203
# Epoch 21/40
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1304 - accuracy: 0.9450 - val_loss: 0.1903 - val_accuracy: 0.9210
# Epoch 22/40
# 68/68 [==============================] - 1s 9ms/step - loss: 0.1276 - accuracy: 0.9473 - val_loss: 0.1900 - val_accuracy: 0.9213
# Epoch 23/40
# 68/68 [==============================] - 1s 8ms/step - loss: 0.1247 - accuracy: 0.9480 - val_loss: 0.1896 - val_accuracy: 0.9220
# Epoch 24/40
# 68/68 [==============================] - 1s 11ms/step - loss: 0.1222 - accuracy: 0.9508 - val_loss: 0.1895 - val_accuracy: 0.9217
# Epoch 25/40
# 68/68 [==============================] - 1s 13ms/step - loss: 0.1198 - accuracy: 0.9499 - val_loss: 0.1893 - val_accuracy: 0.9238
# Epoch 26/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1176 - accuracy: 0.9524 - val_loss: 0.1893 - val_accuracy: 0.9231
# Epoch 27/40
# 68/68 [==============================] - 1s 11ms/step - loss: 0.1154 - accuracy: 0.9537 - val_loss: 0.1895 - val_accuracy: 0.9238
# Epoch 28/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1132 - accuracy: 0.9530 - val_loss: 0.1896 - val_accuracy: 0.9245
# Epoch 29/40
# 68/68 [==============================] - 1s 10ms/step - loss: 0.1113 - accuracy: 0.9562 - val_loss: 0.1898 - val_accuracy: 0.9241
# Epoch 30/40
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1095 - accuracy: 0.9552 - val_loss: 0.1900 - val_accuracy: 0.9238
# Epoch 31/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1076 - accuracy: 0.9567 - val_loss: 0.1905 - val_accuracy: 0.9255
# Epoch 32/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.9578 - val_loss: 0.1909 - val_accuracy: 0.9241
# Epoch 33/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9585 - val_loss: 0.1912 - val_accuracy: 0.9238
# Epoch 34/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1027 - accuracy: 0.9599 - val_loss: 0.1918 - val_accuracy: 0.9234
# Epoch 35/40
# 68/68 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9603 - val_loss: 0.1924 - val_accuracy: 0.9231
# Epoch 36/40
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0998 - accuracy: 0.9613 - val_loss: 0.1929 - val_accuracy: 0.9227
# Epoch 37/40
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0984 - accuracy: 0.9622 - val_loss: 0.1937 - val_accuracy: 0.9220
# Epoch 38/40
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0971 - accuracy: 0.9633 - val_loss: 0.1943 - val_accuracy: 0.9224
# Epoch 39/40
# 68/68 [==============================] - 1s 7ms/step - loss: 0.0958 - accuracy: 0.9635 - val_loss: 0.1948 - val_accuracy: 0.9220
# Epoch 40/40
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0946 - accuracy: 0.9648 - val_loss: 0.1957 - val_accuracy: 0.9217

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
P_train = ((model.predict(X_train) > 0) * 1.0).flatten()
P_test = ((model.predict(X_test) > 0) * 1.0).flatten()
# Out:
# 271/271 [==============================] - 0s 1ms/step
# 91/91 [==============================] - 0s 1ms/step

# %%
cm = confusion_matrix(Y_train, P_train, normalize='true')
cm
# Out:
# array([[0.99095551, 0.00904449],
#        [0.1       , 0.9       ]])

# %%
# Scikit-Learn is transitioning to V1 but it's not available on Colab
# The changes modify how confusion matrices are plotted
def plot_cm(cm):
  classes = ['negative', 'positive']
  df_cm = pd.DataFrame(cm, index=classes, columns=classes)
  ax = sn.heatmap(df_cm, annot=True, fmt='g')
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Target")

plot_cm(cm)

# %%
cm_test = confusion_matrix(Y_test, P_test, normalize='true')
plot_cm(cm_test)

# %%
print("Train F1:", f1_score(Y_train, P_train))
print("Test F1:", f1_score(Y_test, P_test))
# Out:
# Train F1: 0.9304997128087307
# Test F1: 0.7996219281663515

# %%
model.layers
# Out:
# [<keras.src.engine.input_layer.InputLayer at 0x7ecdfc2d5000>,
#  <keras.src.layers.core.dense.Dense at 0x7ecdfc2d5030>]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-3.7505958],
#         [ 3.2542245],
#         [-1.5538678],
#         ...,
#         [ 2.0392063],
#         [ 1.6362331],
#         [-2.9134104]], dtype=float32),
#  array([-0.2543048], dtype=float32)]

# %%
w = model.layers[1].get_weights()[0]

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'jetblue': 975,
#  'thanks': 1725,
#  'for': 753,
#  'having': 855,
#  'us': 1857,
#  'hang': 838,
#  'out': 1265,
#  'at': 195,
#  'tampa': 1707,
#  'airport': 120,
#  'forever': 756,
#  'today': 1765,
#  'it': 966,
#  'really': 1423,
#  'been': 241,
#  'an': 145,
#  'awesome': 215,
#  'experience': 655,
#  'americanair': 141,
#  'was': 1894,
#  'told': 1768,
#  'you': 1992,
#  'could': 452,
#  'only': 1248,
#  'refund': 1439,
#  'me': 1109,
#  'the': 1729,
#  'cost': 448,
#  'of': 1227,
#  'my': 1180,
#  'original': 1257,
#  'return': 1479,
#  'flight': 725,
#  'note': 1213,
#  'had': 828,
#  'booked': 270,
#  'more': 1165,
#  'expensive': 654,
#  'everyone': 635,
#  'else': 602,
#  'outstanding': 1269,
#  'united': 1840,
#  'denver': 517,
#  'to': 1764,
#  'austin': 205,
#  'still': 1660,
#  'on': 1242,
#  'ground': 820,
#  'issue': 963,
#  'is': 961,
#  'lack': 1001,
#  'announcement': 149,
#  'made': 1088,
#  'so': 1608,
#  'late': 1012,
#  'when': 1927,
#  'gate': 793,
#  'agent': 111,
#  'there': 1733,
#  'over': 1270,
#  'hour': 897,
#  'southwestair': 1628,
#  'hold': 880,
#  '30': 36,
#  'min': 1142,
#  'trying': 1806,
#  'rebook': 1426,
#  'cancelled': 314,
#  'flightled': 733,
#  'help': 867,
#  'from': 773,
#  'phl': 1311,
#  'dal': 485,
#  'rebooked': 1427,
#  'tomorrow': 1769,
#  'now': 1220,
#  'that': 1727,
#  'again': 109,
#  'usairways': 1859,
#  'phone': 1314,
#  'called': 308,
#  'number': 1221,
#  'and': 146,
#  'she': 1563,
#  'picked': 1319,
#  'up': 1848,
#  'almost': 129,
#  'immediately': 926,
#  'just': 982,
#  'sent': 1548,
#  'another': 152,
#  'drink': 579,
#  'think': 1738,
#  'have': 853,
#  'free': 765,
#  'drinks': 580,
#  'anyone': 159,
#  'guys': 826,
#  'off': 1228,
#  'if': 921,
#  'every': 634,
#  'employees': 609,
#  'would': 1970,
#  'making': 1095,
#  'effort': 600,
#  'credit': 467,
#  'where': 1928,
#  'due': 586,
#  'delayed': 508,
#  'hours': 898,
#  'instead': 951,
#  've': 1871,
#  '55': 57,
#  'mins': 1146,
#  'about': 74,
#  'flighted': 729,
#  'international': 954,
#  'am': 137,
#  'country': 458,
#  'can': 313,
#  'leave': 1018,
#  'call': 306,
#  'back': 219,
#  'got': 816,
#  'worked': 1958,
#  'trip': 1798,
#  'pay': 1296,
#  'extra': 665,
#  'though': 1745,
#  'not': 1211,
#  'easy': 597,
#  'poor': 1347,
#  'did': 537,
#  'report': 1455,
#  'updated': 1850,
#  'info': 945,
#  'don': 571,
#  'know': 995,
#  'how': 901,
#  'reach': 1417,
#  'them': 1731,
#  'without': 1947,
#  'super': 1681,
#  'long': 1060,
#  'wait': 1883,
#  'your': 1994,
#  'main': 1090,
#  'use': 1861,
#  'voucher': 1881,
#  'book': 269,
#  'last': 1011,
#  'lines': 1043,
#  'are': 173,
#  'busy': 298,
#  'may': 1105,
#  'go': 808,
#  'wife': 1937,
#  'flt': 741,
#  'via': 1874,
#  'dfw': 534,
#  'bought': 276,
#  'swa': 1691,
#  'get': 798,
#  'her': 871,
#  'home': 883,
#  'dm': 561,
#  'plz': 1340,
#  'course': 460,
#  'but': 299,
#  'they': 1735,
#  'were': 1918,
#  'as': 182,
#  'why': 1935,
#  'getting': 800,
#  'put': 1399,
#  'by': 302,
#  'people': 1302,
#  'calling': 309,
#  'platinum': 1333,
#  'desk': 528,
#  'thankfully': 1724,
#  'lounge': 1072,
#  'next': 1197,
#  'door': 574,
#  'impressed': 929,
#  'thank': 1723,
#  'with': 1945,
#  'passbook': 1286,
#  'all': 124,
#  'works': 1961,
#  'much': 1176,
#  'better': 249,
#  'happening': 843,
#  'delta': 514,
#  'took': 1772,
#  'care': 322,
#  'purchase': 1395,
#  'ticket': 1753,
#  'check': 359,
#  'in': 932,
#  'bag': 223,
#  'however': 902,
#  'being': 244,
#  'charged': 352,
#  '25': 29,
#  'dollars': 569,
#  'domestic': 570,
#  'heard': 862,
#  'charge': 351,
#  '1st': 19,
#  'seats': 1533,
#  'no': 1204,
#  'need': 1189,
#  'be': 236,
#  'loyal': 1080,
#  'jb': 973,
#  'customer': 478,
#  'anymore': 158,
#  'already': 132,
#  'spoke': 1639,
#  'line': 1042,
#  'support': 1683,
#  'wasn': 1895,
#  'delay': 507,
#  'engine': 613,
#  'needed': 1190,
#  'makes': 1094,
#  'person': 1307,
#  'stand': 1645,
#  'pilot': 1321,
#  'or': 1254,
#  'paperwork': 1281,
#  'fix': 719,
#  'problem': 1374,
#  'fixed': 720,
#  'ago': 113,
#  'set': 1555,
#  'interview': 956,
#  'days': 493,
#  'hoping': 890,
#  'won': 1950,
#  'filled': 708,
#  'because': 239,
#  'link': 1044,
#  'doesn': 565,
#  'work': 1957,
#  'amp': 144,
#  'asked': 186,
#  'many': 1100,
#  'questions': 1404,
#  'might': 1136,
#  'should': 1569,
#  'seattle': 1534,
#  'strand': 1667,
#  'someone': 1616,
#  'city': 372,
#  'luggage': 1085,
#  'aa': 72,
#  'want': 1890,
#  'earn': 593,
#  'business': 297,
#  'guess': 823,
#  'needs': 1191,
#  'their': 1730,
#  'shit': 1564,
#  'together': 1767,
#  'counter': 456,
#  'catch': 329,
#  'flights': 736,
#  'http': 905,
#  'co': 388,
#  'passengers': 1289,
#  'sitting': 1589,
#  'plane': 1328,
#  'two': 1818,
#  'cmh': 386,
#  'other': 1261,
#  'left': 1021,
#  'usairwaysfail': 1860,
#  'hrs': 904,
#  'months': 1164,
#  'supposed': 1685,
#  'mom': 1158,
#  'whose': 1934,
#  'very': 1873,
#  'upset': 1855,
#  'crews': 469,
#  'surprised': 1688,
#  'arrive': 178,
#  'fuck': 779,
#  'this': 1741,
#  'will': 1939,
#  'never': 1192,
#  'bad': 220,
#  'weather': 1906,
#  'multiple': 1177,
#  'has': 848,
#  'time': 1758,
#  'reservation': 1467,
#  'cant': 318,
#  'through': 1748,
#  'woman': 1948,
#  'who': 1931,
#  'working': 1960,
#  'find': 711,
#  'tonight': 1770,
#  'exec': 647,
#  'online': 1247,
#  'clear': 378,
#  'amazing': 138,
#  'officially': 1233,
#  'favorite': 690,
#  'airline': 117,
#  'day': 492,
#  'like': 1039,
#  'waited': 1884,
#  'bags': 225,
#  'coming': 399,
#  'ahead': 114,
#  'live': 1049,
#  'premium': 1363,
#  'route': 1493,
#  'lhr': 1033,
#  'well': 1916,
#  'didn': 538,
#  'then': 1732,
#  'airplane': 119,
#  'worst': 1967,
#  'fly': 743,
#  'ever': 633,
#  'train': 1783,
#  'attendants': 201,
#  'monday': 1161,
#  're': 1416,
#  'haven': 854,
#  'any': 157,
#  'idea': 919,
#  'what': 1922,
#  '200': 21,
#  'couldn': 453,
#  'even': 630,
#  'give': 802,
#  'food': 752,
#  'comp': 404,
#  'take': 1699,
#  'stranded': 1668,
#  'flying': 747,
#  'new': 1194,
#  'we': 1905,
#  'stuck': 1669,
#  'rather': 1414,
#  'than': 1722,
#  'broken': 285,
#  'charlotte': 356,
#  'service': 1553,
#  'agents': 112,
#  'kind': 992,
#  'way': 1903,
#  'hopefully': 889,
#  'future': 789,
#  'different': 542,
#  'procedure': 1376,
#  'car': 320,
#  'seat': 1530,
#  'lost': 1069,
#  'reimburse': 1446,
#  'one': 1245,
#  'child': 367,
#  'baggage': 224,
#  'handlers': 835,
#  'totally': 1775,
#  'our': 1264,
#  'barely': 228,
#  'run': 1505,
#  'connect': 430,
#  'den': 515,
#  'came': 311,
#  'mail': 1089,
#  'early': 592,
#  'bird': 256,
#  'great': 819,
#  'first': 716,
#  'crew': 468,
#  'takes': 1702,
#  'overhead': 1272,
#  'bin': 254,
#  'space': 1629,
#  'paying': 1297,
#  'customers': 479,
#  'annoyed': 150,
#  'stay': 1657,
#  'please': 1336,
#  'which': 1929,
#  'name': 1183,
#  'tag': 1698,
#  '11': 6,
#  'planes': 1329,
#  '50': 54,
#  'its': 970,
#  '10': 2,
#  '20': 20,
#  'tarmac': 1708,
#  'going': 811,
#  'compensate': 408,
#  'companion': 405,
#  'pass': 1285,
#  'ridiculous': 1485,
#  'hadn': 829,
#  'stopped': 1663,
#  'hotels': 896,
#  'non': 1206,
#  'solve': 1612,
#  'miss': 1152,
#  'funeral': 786,
#  'suck': 1674,
#  'newark': 1195,
#  'checked': 360,
#  'under': 1831,
#  'too': 1771,
#  'happy': 845,
#  'enter': 617,
#  'hey': 873,
#  'remember': 1451,
#  'do': 563,
#  'email': 603,
#  'gotten': 818,
#  'yet': 1989,
#  'delays': 510,
#  'little': 1048,
#  'communication': 403,
#  'goes': 810,
#  'nice': 1199,
#  'routes': 1494,
#  'jet': 974,
#  'blue': 263,
#  'southwest': 1627,
#  'least': 1017,
#  'treat': 1794,
#  'properly': 1385,
#  'heads': 860,
#  'arrived': 179,
#  'those': 1744,
#  'aren': 175,
#  'claim': 373,
#  'point': 1342,
#  'gt': 822,
#  'after': 107,
#  'planned': 1330,
#  'departure': 522,
#  'california': 305,
#  'here': 872,
#  'originally': 1258,
#  'keeping': 985,
#  'safe': 1510,
#  'sister': 1586,
#  'reply': 1454,
#  'ur': 1856,
#  'services': 1554,
#  '18': 15,
#  'response': 1476,
#  'lousy': 1073,
#  'unitedairlines': 1841,
#  'following': 751,
#  'ice': 915,
#  'front': 774,
#  'landed': 1006,
#  'pulled': 1394,
#  'information': 946,
#  'saw': 1520,
#  'helpful': 869,
#  'specific': 1633,
#  'cs': 473,
#  'look': 1062,
#  'apologize': 165,
#  'trouble': 1800,
#  'buffalo': 292,
#  'jfk': 977,
#  'figured': 704,
#  'anything': 160,
#  'make': 1093,
#  'll': 1051,
#  'excuses': 646,
#  'hi': 874,
#  'im': 923,
#  'speak': 1630,
#  'travel': 1788,
#  'minor': 1145,
#  'keeps': 986,
#  'advise': 104,
#  'website': 1908,
#  'wont': 1954,
#  'allow': 126,
#  'thx': 1752,
#  'social': 1609,
#  'media': 1116,
#  'memphis': 1122,
#  'something': 1617,
#  'also': 133,
#  'useless': 1864,
#  'canned': 316,
#  '1k': 18,
#  'let': 1027,
#  'kids': 990,
#  'board': 265,
#  'wish': 1944,
#  'team': 1711,
#  'member': 1120,
#  'pick': 1318,
#  'alone': 130,
#  'clt': 383,
#  'gonna': 814,
#  'connection': 433,
#  'ua': 1822,
#  'change': 345,
#  'music': 1178,
#  'leaving': 1020,
#  'morning': 1166,
#  'auto': 206,
#  'tuesday': 1808,
#  'night': 1201,
#  'horrendous': 891,
#  'flown': 740,
#  'come': 396,
#  'pathetic': 1292,
#  'waiting': 1885,
#  'yesterday': 1988,
#  'class': 374,
#  'passenger': 1288,
#  'win': 1941,
#  'lt': 1082,
#  'mind': 1143,
#  'states': 1655,
#  'maintenance': 1091,
#  'app': 167,
#  'says': 1523,
#  'arriving': 181,
#  'aircraft': 116,
#  'tell': 1714,
#  'unfriendly': 1836,
#  'right': 1486,
#  'whole': 1933,
#  'form': 758,
#  'before': 242,
#  'direct': 545,
#  'address': 99,
#  'plans': 1331,
#  'system': 1696,
#  'reflight': 1438,
#  'booking': 271,
#  'problems': 1375,
#  'disconnect': 553,
#  'between': 250,
#  'face': 670,
#  'enough': 616,
#  'miles': 1139,
#  'enjoy': 615,
#  'perfect': 1304,
#  'coffee': 392,
#  'tracking': 1781,
#  'tells': 1716,
#  'nothing': 1215,
#  'less': 1025,
#  'easily': 595,
#  'company': 406,
#  'experienced': 656,
#  'personal': 1308,
#  'caused': 332,
#  'ruining': 1503,
#  'ashamed': 184,
#  'gave': 795,
#  'wrong': 1974,
#  'nothappy': 1214,
#  'vouchers': 1882,
#  'runway': 1507,
#  'saturday': 1518,
#  'bwi': 301,
#  'appreciate': 170,
#  'power': 1356,
#  'laptop': 1008,
#  'iphone': 960,
#  'missing': 1154,
#  'good': 815,
#  'holder': 881,
#  'conditions': 422,
#  'arrival': 177,
#  'de': 496,
#  'icing': 916,
#  'three': 1747,
#  'far': 683,
#  'sure': 1686,
#  'taking': 1703,
#  '15': 11,
#  '12': 7,
#  '40': 48,
#  '45': 51,
#  'minutes': 1149,
#  'jetway': 976,
#  'hotel': 895,
#  '32': 41,
#  'counting': 457,
#  'gotta': 817,
#  'record': 1434,
#  'air': 115,
#  'delivered': 512,
#  'destination': 530,
#  'frequent': 767,
#  'traveler': 1790,
#  'treated': 1795,
#  'offer': 1229,
#  'pls': 1338,
#  'start': 1649,
#  'luv': 1086,
#  'ya': 1978,
#  'finally': 710,
#  'nashville': 1184,
#  'answers': 156,
#  'away': 214,
#  'chicago': 365,
#  'drove': 585,
#  'prepared': 1364,
#  'bringing': 283,
#  'does': 564,
#  'sense': 1547,
#  'yay': 1980,
#  'nuts': 1223,
#  'cold': 393,
#  'eventually': 632,
#  'explained': 660,
#  'virginamerica': 1878,
#  'understanding': 1833,
#  'helped': 868,
#  'best': 248,
#  'lady': 1002,
#  'advance': 102,
#  '24': 27,
#  'prior': 1370,
#  'tried': 1797,
#  'earlier': 591,
#  'wanted': 1891,
#  '300': 37,
#  'fees': 697,
#  'sfo': 1558,
#  'say': 1521,
#  'consistent': 437,
#  'high': 875,
#  'quality': 1402,
#  'keep': 984,
#  'quick': 1406,
#  'serious': 1549,
#  'question': 1403,
#  'showing': 1574,
#  'place': 1325,
#  'fyi': 790,
#  'dropped': 584,
#  'able': 73,
#  'conf': 423,
#  'appreciated': 171,
#  'suppose': 1684,
#  'til': 1756,
#  'glad': 806,
#  'damaged': 488,
#  'answer': 153,
#  'hung': 911,
#  'disappointed': 549,
#  'losing': 1067,
#  'fill': 707,
#  'soon': 1620,
#  'land': 1005,
#  'hope': 888,
#  'feedback': 694,
#  'virgin': 1877,
#  'went': 1917,
#  'smooth': 1603,
#  'ride': 1484,
#  'wow': 1972,
#  'thinking': 1739,
#  'same': 1515,
#  'ps': 1389,
#  'overnight': 1273,
#  'meet': 1117,
#  'either': 601,
#  'connections': 434,
#  'tx': 1819,
#  'see': 1538,
#  'year': 1983,
#  'love': 1074,
#  'consider': 435,
#  'fare': 684,
#  'price': 1367,
#  'try': 1805,
#  'father': 688,
#  'loved': 1076,
#  'likely': 1040,
#  'slow': 1600,
#  'internet': 955,
#  'addressed': 100,
#  'fee': 693,
#  'yes': 1987,
#  'cust': 477,
#  'svc': 1689,
#  'said': 1513,
#  'evening': 631,
#  'further': 788,
#  'both': 274,
#  'during': 588,
#  'broke': 284,
#  'open': 1250,
#  'camera': 312,
#  'read': 1419,
#  'believe': 245,
#  'incident': 934,
#  'fault': 689,
#  'sw': 1690,
#  'done': 572,
#  'ive': 971,
#  'boarding': 267,
#  'catering': 330,
#  'always': 136,
#  'nightmare': 1202,
#  'fail': 672,
#  'kidding': 989,
#  'talked': 1705,
#  'human': 908,
#  'asking': 187,
#  'follow': 749,
#  'vacation': 1868,
#  'finish': 715,
#  'some': 1613,
#  'text': 1721,
#  'carrier': 325,
#  'card': 321,
#  'nope': 1209,
#  'apparently': 168,
#  'times': 1760,
#  'wtf': 1976,
#  'looks': 1065,
#  'handling': 836,
#  'connecting': 432,
#  'thru': 1750,
#  'impossible': 928,
#  'actually': 94,
#  'final': 709,
#  'attitude': 203,
#  'these': 1734,
#  'mco': 1107,
#  'iad': 913,
#  'fingers': 714,
#  'crossed': 471,
#  'four': 762,
#  'meeting': 1118,
#  'atlanta': 197,
#  'slept': 1599,
#  'security': 1537,
#  'onto': 1249,
#  'crying': 472,
#  'baby': 218,
#  'situation': 1590,
#  'drop': 583,
#  'incredibly': 941,
#  'unacceptable': 1827,
#  'issues': 965,
#  'based': 229,
#  'things': 1737,
#  'control': 443,
#  'wifi': 1938,
#  'tv': 1812,
#  'double': 576,
#  'comment': 400,
#  'anywhere': 162,
#  'south': 1626,
#  'florida': 739,
#  'gone': 813,
#  'hello': 866,
#  'forgot': 757,
#  'thought': 1746,
#  'mosaic': 1167,
#  'perks': 1306,
#  'part': 1283,
#  'checking': 362,
#  '60': 61,
#  'upgrade': 1852,
#  'solution': 1611,
#  'show': 1572,
#  'track': 1780,
#  'disappeared': 548,
#  'dulles': 587,
#  'lax': 1013,
#  'thursday': 1751,
#  'honest': 884,
#  'reschedule': 1464,
#  'btw': 290,
#  'intl': 957,
#  'flightd': 728,
#  'area': 174,
#  'pretty': 1365,
#  'probably': 1373,
#  'plus': 1339,
#  'hearing': 863,
#  'overbooked': 1271,
#  'since': 1583,
#  'file': 705,
#  'cool': 444,
#  'pre': 1359,
#  'thing': 1736,
#  'single': 1585,
#  'philly': 1310,
#  'deal': 498,
#  'boarded': 266,
#  'joke': 980,
#  'computer': 417,
#  'ing': 948,
#  'complain': 411,
#  'public': 1391,
#  'afternoon': 108,
#  'six': 1591,
#  'layover': 1014,
#  'party': 1284,
#  'assist': 191,
#  'flts': 742,
#  'except': 643,
#  'message': 1127,
#  'trust': 1804,
#  'bna': 264,
#  'rdu': 1415,
#  'most': 1168,
#  'excellent': 642,
#  'fa': 667,
#  'such': 1673,
#  'warm': 1893,
#  'onboard': 1243,
#  'welcome': 1915,
#  'wonder': 1951,
#  'hate': 851,
#  'dealing': 499,
#  'airlines': 118,
#  'policies': 1345,
#  'resolution': 1469,
#  'jan': 972,
#  'options': 1253,
#  'returning': 1481,
#  'hanging': 839,
#  'mistake': 1155,
#  'feel': 695,
#  'requested': 1460,
#  'reward': 1482,
#  'points': 1343,
#  'used': 1862,
#  'he': 856,
#  'refused': 1443,
#  'screwed': 1528,
#  'big': 252,
#  '1hr': 17,
#  '2nd': 34,
#  'wouldn': 1971,
#  'view': 1876,
#  'changes': 347,
#  'outside': 1268,
#  'flightr': 735,
#  'acceptable': 81,
#  'entire': 619,
#  'dca': 495,
#  'nobody': 1205,
#  'knows': 998,
#  'pm': 1341,
#  'job': 979,
#  'angry': 147,
#  'kudos': 999,
#  'fast': 686,
#  'congrats': 429,
#  'systems': 1697,
#  'down': 577,
#  'plan': 1327,
#  'american': 140,
#  'cuz': 482,
#  'behind': 243,
#  'schedule': 1524,
#  'staff': 1644,
#  'cabin': 304,
#  'bos': 272,
#  'ogg': 1235,
#  'using': 1865,
#  'hard': 846,
#  'given': 803,
#  'legs': 1024,
#  'confirm': 425,
#  'informed': 947,
#  'flightlation': 731,
#  'letter': 1029,
#  'sna': 1604,
#  'causes': 333,
#  'provide': 1386,
#  'transportation': 1787,
#  'wedding': 1909,
#  'watch': 1899,
#  '3hrs': 45,
#  'sju': 1593,
#  'worse': 1966,
#  'handle': 833,
#  'hangs': 840,
#  'middle': 1134,
#  'mad': 1087,
#  'unhelpful': 1839,
#  'rude': 1501,
#  '2hrs': 33,
#  'beyond': 251,
#  'spiritairlines': 1638,
#  'receive': 1429,
#  'assistance': 192,
#  'apology': 166,
#  'disappointing': 550,
#  'airways': 122,
#  'answering': 155,
#  'ugh': 1824,
#  'ok': 1237,
#  'insane': 949,
#  'request': 1459,
#  'completely': 415,
#  'paid': 1277,
#  'group': 821,
#  'doing': 568,
#  'while': 1930,
#  'isn': 962,
#  'supervisor': 1682,
#  'regarding': 1445,
#  'travels': 1793,
#  'stuff': 1670,
#  'carry': 326,
#  'weight': 1914,
#  'spent': 1637,
#  'account': 86,
#  'houston': 900,
#  'express': 662,
#  '35': 42,
#  'additional': 98,
#  'delivery': 513,
#  'crazy': 466,
#  'update': 1849,
#  'infant': 943,
#  'children': 368,
#  'nyc': 1225,
#  'unbelievable': 1829,
#  'inbound': 933,
#  'equipment': 622,
#  'moving': 1172,
#  'happens': 844,
#  'often': 1234,
#  'la': 1000,
#  'gives': 804,
#  'absolute': 77,
#  'found': 761,
#  'straight': 1666,
#  'talk': 1704,
#  'rescheduled': 1465,
#  'okay': 1238,
#  'large': 1009,
#  'real': 1421,
#  'god': 809,
#  'man': 1096,
#  'past': 1291,
#  'assignment': 190,
#  'chairman': 342,
#  'preferred': 1361,
#  'row': 1496,
#  'employee': 608,
#  'telling': 1715,
#  'fit': 717,
#  'clearly': 379,
#  'nah': 1182,
#  'dont': 573,
#  'humans': 909,
#  'respond': 1473,
#  'relations': 1450,
#  'midnight': 1135,
#  'cheers': 363,
#  'mean': 1111,
#  'posted': 1355,
#  'usair': 1858,
#  '800': 69,
#  'calls': 310,
#  'contact': 438,
#  'understand': 1832,
#  'missed': 1153,
#  'mechanical': 1114,
#  'failure': 675,
#  'lose': 1066,
#  '400': 49,
#  'mon': 1160,
#  'status': 1656,
#  'match': 1103,
#  'program': 1379,
#  'weeks': 1913,
#  'emailed': 604,
#  'inside': 950,
#  'money': 1162,
#  'phones': 1315,
#  'suggestions': 1677,
#  'frustrated': 776,
#  'items': 968,
#  'embarrassing': 606,
#  'third': 1740,
#  ...}

# %%
# let's look at the weights for each word
# try it with different threshold values!
threshold = 2

print("Most positive words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight > threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: -x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most positive words:
# thank 9.80344
# thanks 9.359368
# worries 8.332844
# great 7.918024
# awesome 7.294099
# love 7.2684517
# excellent 7.085985
# kudos 6.8327403
# amazing 6.4486856
# best 6.133733

# %%
print("Most negative words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight < -threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most negative words:
# worst -9.383829
# paid -7.8115005
# not -7.752267
# rude -7.5534744
# disappointed -7.2310944
# nothing -6.7925696
# website -6.7900267
# hung -6.6506667
# instead -6.5720963
# weren -6.1810594
